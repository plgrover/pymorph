# %%
# %matplotlib widget
import os,sys
import csv
import copy
import math
import collections
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from clawpack import pyclaw
from clawpack import riemann
from IPython.display import HTML
import numpy as np
from scipy.integrate import simps, trapz
from scipy.interpolate import interp1d
from scipy import signal
sys.path.append("/pymorph")
from schemes.weno import get_left_flux,get_right_flux, get_Max_Phase_Speed
from schemes.weno import get_stencil
import sediment_transport.sed_trans as sedtrans
import morph_geom_lib as mgl

from models.shallow_water_solver import shallow_water_solver
from schemes.avalanche_scheme import *

from matplotlib.collections import LineCollection
from mpl_toolkits.mplot3d import Axes3D

from IPython.display import display, Math, Latex
from matplotlib import animation, rc

rc('animation', html='html5')

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
plt.style.use(['default'])

# %% [markdown]
# ## A3DOWN Updates

# %%
profile_folder = '/pymorph/notebooks/Paper_3/flume_profile_smoothed_v002.txt'
xc, z0 = mgl.readQueensFlume(profile_folder,1)

fig = plt.figure(figsize=(16, 3))
#plt.plot(xc,z0,'b')

dunes = 6

xsaw = np.linspace(0, 1,500)
simTime = 60*10 # Runtime in seconds
dt = 0.5 # Time step size (s)

zsaw = 0.076*(signal.sawtooth(2*dunes*np.pi * xsaw) + 1.)/2
xsaw = xsaw*xc.max()*dunes*0.5
#plt.plot(xsaw,zsaw)


dx = xsaw[1]-xsaw[0]
znew, iterations1 = avalanche_model(dx,xsaw, zsaw, adjustment_angle=28.)
# Now flip it to run in reverse
zflip = np.flip(znew, axis=0)
zflip, iterations1 = avalanche_model(dx,xsaw, zflip, adjustment_angle=28.)
znew = np.flip(zflip, axis=0)

znew = (znew - np.min(znew))/np.ptp(znew)
znew = znew*0.076

plt.plot(xsaw,znew,'-',color='k')
plt.axhline(0.357)
print(dx)
plt.xlabel('x (m)')
plt.ylabel('z (m)')
# Out:
# Z: 87
# 0.01569138276553106
# Text(0, 0.5, 'z (m)')

# %%
#--------------------------------
# Set up the geometry
#--------------------------------
xc = xsaw.copy()
zc = znew.copy()
x0 = xsaw.copy()
z0 = znew.copy()
nx = len(xc)

#--------------------------------
# Set up the Boundary conditions
#--------------------------------
# 32 cm Case 
Qc132 = 0.0455
Qc120 = 0.020
B = 0.76
Qtotal32 = Qc132 * 3.
Qtotal20 = Qc120 * 3.
q32cm = Qtotal32 / B
q20cm = Qtotal20 / B

# The ubar for this is 0.561 m/s

hout = 0.357
Qin = q32cm

#--------------------------------
# Set up the Domain Conditions
#--------------------------------
Mannings = 0.048
Slope = 1.26/1000.
# Sediment properties
D50 = 0.001     # Particle Diameter
rho_particule = 2650
nP = 0.4
#--------------------------------
#  Setup the model run parameters
#--------------------------------
simTime = 1.*60       # Runtime in seconds
dt = 5                # Time step size (s)
nt = int(simTime/dt)  # Number of time steps
extractionInterval = 60.*5


#--------------------------------
# Initalize the model
#--------------------------------
sws = shallow_water_solver(kernel_language='Fortran')
sws.set_solver(max_steps=100000)
sws.set_state_domain(xc,zc)
sws.set_mannings_source_term(mannings=Mannings, slope=Slope)
sws.set_Dirichlet_BC(hout,Qin)
sws.set_inital_conditions(hout, 0.0)
sws.set_controller(tfinal=300., num_output_times=3)
sws.run()
cntrl = sws.get_controller()

#--------------------------------
# Initalize the model
#--------------------------------
h = sws.get_hf()
u = sws.get_uf()
q = sws.get_qf()

roe_speed = np.zeros(nx)
flux = np.zeros(nx)
qbedload = np.zeros(nx)
verts = []
tsteps = []
iterations = 0
cntr = 0

time_series = collections.OrderedDict()
time = 0

#--------------------------------
#  Run the model
#--------------------------------
for n in range(1,nt):  
    zn = zc.copy() 
    for i in range(0,nx): #i=2
        zloc = get_stencil(zn,i-2,i+4)        
        # Since k=3
        # stencil is i-2 to i+2 
        qloc = get_stencil(qbedload,i-2,i+4)
        if len(qloc)!=6:
            raise ValueError('Stencil is incorrect')
 
        # Determine the Upwind flux
        # The 0.5 comes from the c+abs(c) which is 2 if the wave speed is +ive
        # this is the evaluation of the left and right based fluxes. Eq. 18 and 19        
        if (zloc[3]-zloc[2]) == 0.0:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2]) )
        else:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2])/ (zloc[3]-zloc[2]) )
        
        if roe_speed[i] >= 0.0:
            flux[i] = get_left_flux(qloc)
        else:
            flux[i] = get_right_flux(qloc)
        
    # Need the sign of the phase speed
    # Need to check this out
    for i in range(0,nx): #i=2       
        floc = get_stencil(flux,i-1,i+1)
        zc[i] = zn[i]-(1./(1.-nP))*dt/dx*(floc[1]-floc[0])
    
    bed_max_delta = np.max(np.abs(zn - zc))
    
    # Apply the avalanche model
    zc, iterations1 = avalanche_model(dx,xc, zc, adjustment_angle=28.)
    # Now flip it to run in reverse
    zflip = np.flip(zc, axis=0)
    zflip, iterations1 = avalanche_model(dx,xc, zflip, adjustment_angle=28.)
    zc = np.flip(zflip, axis=0)
    
    #zc = z_updated.copy()
    
    # Re-run the solver and updated the sediment transport
    # Check if the avalanche model was updated OR the bed changed greater than the threshold
    #if iterations > 10 or bed_max_delta > 0.00005:
    iterations+=1
    if iterations > 2:        
        sws = shallow_water_solver(kernel_language='Fortran')
        sws.set_solver(max_steps=100000)
        sws.set_state_domain(xc,zc)
        sws.set_mannings_source_term(mannings=Mannings, slope=Slope)
        sws.set_conditions_from_previous(h, q)
        sws.set_Dirichlet_BC(hout,Qin)
        sws.set_controller(tfinal=10., num_output_times=1)
        sws.run()
        cntrl = sws.get_controller()      

        h = sws.get_hf()
        u = sws.get_uf()
        q = sws.get_qf()
        surf = h + zc
        
        iterations = 0
        
    slope = np.gradient(zc,dx)
    
    if 1==0:
        # ----------------------------------
        # Apply the two-step smooting scheme Eq. 6 in Niemann et al 2011.
        # ----------------------------------
        zhat = np.zeros(nx)
        for i in range(0, nx):  # i=2
            zlocal = get_stencil(zc, i - 1, i + 2)
            zhat[i] = 0.5*zlocal[1] + 0.25*(zlocal[0]+zlocal[2])

        for i in range(0, nx):
            zhatlocal = get_stencil(zhat, i - 1, i + 2)
            zc[i] = (3./2.)*zhatlocal[1] - 0.25*(zhatlocal[0]+zhatlocal[2])


    ## Nov 13 2018 - Can modify later
    for i in range(0,nx): #i=2        
        #zlocal = get_stencil(zc,i-2,i+2)
        #qbedload[i] = sedtrans.get_unit_bed_load2(h[i],u[i],D50,rho_particule,type='bagnold')
        qbedload[i] = sedtrans.get_unit_bed_load_slope(h[i],u[i],D50,slope[i], 
                                                       rho_particule, 
                                                       angleReposeDegrees = 30.0, 
                                                       type='bagnold',
                                                        useSlopeAdjust=False)
    
    #time_series[time] = zc
    #time+=1
    
    if (n*dt / extractionInterval) == math.floor(n*dt / extractionInterval):
        verts.append(list(zip(xc.copy(),zc.copy())))
        tsteps.append(n*dt/60.)        
        np.save('flume_dunes', verts)
        Courant = get_Max_Phase_Speed(qbedload,zc,nP)*dt/dx
        print('Time step: {0} mins - uavg: {1} - Elevation {2}'.format(n*dt/60., u.mean(), surf.mean()))
        print('Courant number: {0}'.format(Courant))
        
print('Done')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-133-27673270573f> in <module>
#      54 sws.set_inital_conditions(hout, 0.0)
#      55 sws.set_controller(tfinal=300., num_output_times=3)
# ---> 56 sws.run()
#      57 cntrl = sws.get_controller()
#      58
#
# /pymorph/models/shallow_water_solver.py in run(self)
#     220         status = None
#     221         if self.controller != None and self.state!=None:
# --> 222             status = self.controller.run()
#     223         else:
#     224             raise ValueError('Model is not parameterized...')
#
# /clawpack/pyclaw/src/pyclaw/controller.py in run(self)
#     351                                         self.output_file_prefix,
#     352                                         write_aux,
# --> 353                                         self.output_options)
#     354
#     355         self.write_F('w')
#
# /clawpack/pyclaw/src/pyclaw/solution.py in write(self, frame, path, file_format, file_prefix, write_aux, options, write_p)
#     293             if file_prefix is None:
#     294                 write_func(self,frame,path,write_aux=write_aux,
# --> 295                             options=options,write_p=write_p)
#     296             else:
#     297                 write_func(self,frame,path,file_prefix=file_prefix,
#
# /clawpack/pyclaw/src/petclaw/fileio/petsc.py in write(solution, frame, path, file_prefix, write_aux, options, write_p)
#      92             state.gpVec.view(q_viewer)
#      93         else:
# ---> 94             state.gqVec.view(q_viewer)
#      95
#      96         if write_aux:
#
# PETSc/Vec.pyx in petsc4py.PETSc.Vec.view()
#
# Error: error code 16
# [0] VecView() line 590 in /tmp/pip-install-zpqu7s7y/petsc/src/vec/vec/interface/vector.c
# [0] VecView_MPI_DA() line 714 in /tmp/pip-install-zpqu7s7y/petsc/src/dm/impls/da/gr2.c
# [0] DMDAArrayMPIIO() line 614 in /tmp/pip-install-zpqu7s7y/petsc/src/dm/impls/da/gr2.c
# [0] PetscViewerBinaryWrite() line 942 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/impls/binary/binv.c
# [0] PetscViewerSetUp() line 337 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/interface/view.c
# [0] PetscViewerSetUp_Binary() line 1361 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/impls/binary/binv.c
# [0] PetscViewerFileSetUp_BinaryMPIIO() line 1295 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/impls/binary/binv.c
# [0] VecView() line 590 in /tmp/pip-install-zpqu7s7y/petsc/src/vec/vec/interface/vector.c
# [0] VecView_MPI_DA() line 714 in /tmp/pip-install-zpqu7s7y/petsc/src/dm/impls/da/gr2.c
# [0] DMDAArrayMPIIO() line 614 in /tmp/pip-install-zpqu7s7y/petsc/src/dm/impls/da/gr2.c
# [0] PetscViewerBinaryWrite() line 942 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/impls/binary/binv.c
# [0] PetscViewerSetUp() line 337 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/interface/view.c
# [0] PetscViewerSetUp_Binary() line 1361 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/impls/binary/binv.c
# [0] PetscViewerFileSetUp_BinaryMPIIO() line 1295 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/impls/binary/binv.c

# %%
fig = plt.figure(figsize=(14, 6))
plt.plot(xc,zc)
plt.plot(x0,z0)
plt.plot(xc, surf)

# %%
dune_height = np.zeros(len(tsteps))

for i in range(0,len(tsteps)):
    zprofile = np.zeros(len(verts[i]))
    for j in range(0, len(verts[i])):
        zprofile[j] = verts[i][j][1]
    dune_height[i] = zprofile[100:400].max() - zprofile[100:400].min()

plt.plot(tsteps, dune_height)

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure(figsize=(12, 3))
ax = plt.axes(xlim=(0, 8), ylim=(0, 0.1))
plt.plot(x0,z0)
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = xc
    y = time_series[i]
    line.set_data(x, y)
    return line,
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=time, interval=3, blit=True)
HTML(anim.to_html5_video())
# Out:
# 2019-05-10 21:19:00,291 INFO CLAW: Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# 2019-05-10 21:19:00,293 INFO CLAW: MovieWriter.run: running command: ['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '1200x300', '-pix_fmt', 'rgba', '-r', '333.3333333333333', '-loglevel', 'quiet', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/tmp/tmpwqim67o_/temp.m4v']
# <video width="1200" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## High Order Scheme

# %%
#--------------------------------
# Set up the geometry
#--------------------------------
xc = xsaw.copy()
zc = znew.copy()
x0 = xsaw.copy()
z0 = znew.copy()
nx = len(xc)

#--------------------------------
# Set up the Boundary conditions
#--------------------------------
# 32 cm Case 
Qc132 = 0.0455
Qc120 = 0.020
B = 0.76
Qtotal32 = Qc132 * 3.
Qtotal20 = Qc120 * 3.
q32cm = Qtotal32 / B
q20cm = Qtotal20 / B

# The ubar for this is 0.561 m/s

hout = 0.237
Qin = q20cm

#--------------------------------
# Set up the Domain Conditions
#--------------------------------
Mannings = 0.048
Slope = 1.26/1000.
# Sediment properties
D50 = 0.001     # Particle Diameter
rho_particule = 2650
nP = 0.4
#--------------------------------
#  Setup the model run parameters
#--------------------------------
simTime = 60*120       # Runtime in seconds
dt = 10                # Time step size (s)
nt = int(simTime/dt)  # Number of time steps
extractionInterval = 60.*1


#--------------------------------
# Initalize the model
#--------------------------------
sws = shallow_water_solver(kernel_language='Fortran')
sws.set_solver(max_steps=100000)
sws.set_state_domain(xc,zc)
sws.set_mannings_source_term(mannings=Mannings, slope=Slope)
sws.set_Dirichlet_BC(hout,Qin)
sws.set_inital_conditions(hout, 0.0)
sws.set_controller(tfinal=300., num_output_times=3)
sws.run()
cntrl = sws.get_controller()

#--------------------------------
# Initalize the model
#--------------------------------
h = sws.get_hf()
u = sws.get_uf()
q = sws.get_qf()

roe_speed = np.zeros(nx)
flux = np.zeros(nx)
qbedload = np.zeros(nx)
verts = []
tsteps = []
iterations = 0
cntr = 0

time_series = collections.OrderedDict()
time = 0

#--------------------------------
#  Run the model
#--------------------------------
for n in range(1,nt):  
    zn = zc.copy() 
    znp1  = zc.copy() 
    znp12  = zc.copy() 
    znp2  = zc.copy() 
    znp32  = zc.copy() 
    roe_speed = np.zeros(nx)
    flux = np.zeros(nx)
    ## Step 1
    for i in range(0,nx): 
        zloc = get_stencil(zn,i-2,i+4)
        qloc = get_stencil(qbedload,i-2,i+4)
        #upwind flux
        # The 0.5 comes from the c+abs(c) which is 2 if the wave speed is +ive
        # this is the evaluation of the left and right based fluxes. Eq. 18 and 19
        
        if (zloc[3]-zloc[2]) == 0.0:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2]) )
        else:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2])/ (zloc[3]-zloc[2]) )
        
        if roe_speed[i] >= 0.0:
            flux[i] = get_left_flux(qloc)
        else:
            flux[i] = get_right_flux(qloc)

    for i in range(0,nx): #i=2       
        floc = get_stencil(flux,i-1,i+1)
        # This is essentially eq. 8. 
        znp1[i] = zn[i]-(1./(1.-nP))*(dt/(1.0*dx))*(floc[1]-floc[0])
        
    sws = shallow_water_solver(kernel_language='Fortran')
    sws.set_solver(max_steps=100000)
    sws.set_state_domain(xc,znp1)
    sws.set_mannings_source_term(mannings=Mannings, slope=Slope)
    sws.set_conditions_from_previous(h, q)
    sws.set_Dirichlet_BC(hout,Qin)
    sws.set_controller(tfinal=5., num_output_times=1)
    sws.run()
    cntrl = sws.get_controller()      

    h = sws.get_hf()
    u = sws.get_uf()
    q = sws.get_qf()
    surf = h + znp1
    
    for i in range(0,nx): #i=2        
        qbedload[i] = sedtrans.get_unit_bed_load_slope(h[i],u[i],D50,slope[i], 
                                                       rho_particule, 
                                                       angleReposeDegrees = 30.0, 
                                                       type='bagnold',
                                                        useSlopeAdjust=False)
        
    
    # -------------------------
    # Step 2
    # -------------------------
    for i in range(0,nx): 
        zloc = get_stencil(znp1,i-2,i+4)
        qloc = get_stencil(qbedload,i-2,i+4)
        #upwind flux
        # The 0.5 comes from the c+abs(c) which is 2 if the wave speed is +ive
        # this is the evaluation of the left and right based fluxes. Eq. 18 and 19
        
        if (zloc[3]-zloc[2]) == 0.0:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2]) )
        else:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2])/ (zloc[3]-zloc[2]) )
        
        if roe_speed[i] >= 0.0:
            flux[i] = get_left_flux(qloc)
        else:
            flux[i] = get_right_flux(qloc)

    for i in range(0,nx): #i=2       
        floc = get_stencil(flux,i-1,i+1)
        # This is essentially eq. 8. 
        znp2[i] = znp1[i]-(1./(1.-nP))*(dt/(1.0*dx))*(floc[1]-floc[0])
        
    # -------------------------
    # Step 3
    # -------------------------
    znp12 = 0.75*zn + 0.25*znp2
    
    sws = shallow_water_solver(kernel_language='Fortran')
    sws.set_solver(max_steps=100000)
    sws.set_state_domain(xc,znp12)
    sws.set_mannings_source_term(mannings=Mannings, slope=Slope)
    sws.set_conditions_from_previous(h, q)
    sws.set_Dirichlet_BC(hout,Qin)
    sws.set_controller(tfinal=5., num_output_times=1)
    sws.run()
    cntrl = sws.get_controller()      

    h = sws.get_hf()
    u = sws.get_uf()
    q = sws.get_qf()
    surf = h + znp12
    
    for i in range(0,nx): #i=2        
        qbedload[i] = sedtrans.get_unit_bed_load_slope(h[i],u[i],D50,slope[i], 
                                                       rho_particule, 
                                                       angleReposeDegrees = 30.0, 
                                                       type='bagnold',
                                                        useSlopeAdjust=False)        
    
    # -------------------------
    # Step 4
    # -------------------------
    for i in range(0,nx): 
        zloc = get_stencil(znp12,i-2,i+4)
        qloc = get_stencil(qbedload,i-2,i+4)
        #upwind flux
        # The 0.5 comes from the c+abs(c) which is 2 if the wave speed is +ive
        # this is the evaluation of the left and right based fluxes. Eq. 18 and 19
        
        if (zloc[3]-zloc[2]) == 0.0:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2]) )
        else:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2])/ (zloc[3]-zloc[2]) )
        
        if roe_speed[i] >= 0.0:
            flux[i] = get_left_flux(qloc)
        else:
            flux[i] = get_right_flux(qloc)

    for i in range(0,nx): #i=2       
        floc = get_stencil(flux,i-1,i+1)
        # This is essentially eq. 8. 
        znp32[i] = znp12[i]-(1./(1.-nP))*(dt/(1.0*dx))*(floc[1]-floc[0])
        
    # -------------------------
    # Step 5
    # -------------------------
    zc = (1./3.)*zn + (2./3.)*znp32
        
    sws = shallow_water_solver(kernel_language='Fortran')
    sws.set_solver(max_steps=100000)
    sws.set_state_domain(xc,zc)
    sws.set_mannings_source_term(mannings=Mannings, slope=Slope)
    sws.set_conditions_from_previous(h, q)
    sws.set_Dirichlet_BC(hout,Qin)
    sws.set_controller(tfinal=5., num_output_times=1)
    sws.run()
    cntrl = sws.get_controller()      

    h = sws.get_hf()
    u = sws.get_uf()
    q = sws.get_qf()
    surf = h + zc
    
    for i in range(0,nx): #i=2        
        qbedload[i] = sedtrans.get_unit_bed_load_slope(h[i],u[i],D50,slope[i], 
                                                       rho_particule, 
                                                       angleReposeDegrees = 30.0, 
                                                       type='bagnold',
                                                        useSlopeAdjust=False)
    
    # Apply the avalanche model
    zc, iterations1 = avalanche_model(dx,xc, zc, adjustment_angle=28.)
    # Now flip it to run in reverse
    zflip = np.flip(zc, axis=0)
    zflip, iterations1 = avalanche_model(dx,xc, zflip, adjustment_angle=28.)
    zc = np.flip(zflip, axis=0)
    
    if (n*dt / extractionInterval) == math.floor(n*dt / extractionInterval):
        verts.append(list(zip(xc.copy(),zc.copy())))
        tsteps.append(n*dt)        
        np.save('flume_dunes', verts)
        Courant = get_Max_Phase_Speed(qbedload,zc,nP)*dt/dx
        print('Time step: {0} mins - uavg: {1} - Elevation {2}'.format(n*dt/60., u.mean(), surf.mean()))
        print('Courant number: {0}'.format(Courant))
        
print('Done')


fig = plt.figure(figsize=(14, 6))
plt.plot(xc,zc)
plt.plot(x0,z0)
plt.plot(xc, surf)
# Out:
# 2019-05-10 23:07:17,213 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:07:30,955 INFO CLAW: Solution 1 computed for time t=100.000000
# 2019-05-10 23:07:47,371 INFO CLAW: Solution 2 computed for time t=200.000000
# 2019-05-10 23:08:01,617 INFO CLAW: Solution 3 computed for time t=300.000000
# 2019-05-10 23:08:01,747 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:02,466 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:02,579 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:03,305 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:03,403 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:04,166 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:04,341 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:05,215 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:05,330 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:06,114 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:06,242 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:06,918 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:07,034 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:07,747 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:07,894 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:08,691 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:08,795 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:09,526 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:09,839 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:10,490 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:10,644 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:11,730 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:11,978 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:13,124 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:13,441 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:14,464 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:14,607 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:15,565 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:15,700 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:16,669 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:17,081 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:18,049 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:18,197 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:19,020 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:19,145 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:19,902 INFO CLAW: Solution 1 computed for time t=5.000000
# Time step: 1.0 mins - uavg: 0.3876252986787973 - Elevation 0.24494643973968125
# Courant number: 0.1485859748927314
# 2019-05-10 23:08:20,303 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:21,420 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:21,583 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:22,575 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:22,715 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:23,562 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:23,796 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:24,489 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:24,621 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:25,332 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:25,422 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:26,263 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:26,522 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:27,244 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:27,357 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:28,120 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:28,223 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:28,965 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:29,339 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:30,040 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:30,144 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:30,883 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:30,988 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:31,760 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:32,042 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:32,746 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:32,857 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:33,588 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:33,699 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:34,447 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:34,945 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:35,590 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:35,707 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:36,471 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:36,586 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:37,358 INFO CLAW: Solution 1 computed for time t=5.000000
# Time step: 2.0 mins - uavg: 0.3873660184935649 - Elevation 0.24503405195569894
# Courant number: 0.39271167118489103
# 2019-05-10 23:08:37,638 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:38,453 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:38,553 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:39,334 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:39,470 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:40,154 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:40,469 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:41,585 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:41,705 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:42,539 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:42,702 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:43,414 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:43,707 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:44,429 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:44,543 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:45,265 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:45,369 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:46,152 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:46,546 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:47,413 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:47,528 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:48,284 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:48,395 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:49,551 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:49,970 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:50,936 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:51,071 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:52,139 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:52,288 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:53,171 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:53,411 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:54,340 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:54,450 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:55,192 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:55,289 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:55,992 INFO CLAW: Solution 1 computed for time t=5.000000
# Time step: 3.0 mins - uavg: 0.3871377096372257 - Elevation 0.24510689288023613
# Courant number: 0.289412606483609
# 2019-05-10 23:08:56,352 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:57,010 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:57,104 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:57,853 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:57,938 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:58,666 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:58,985 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:08:59,731 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:08:59,851 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:00,555 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:00,677 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:01,361 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:01,658 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:02,522 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:02,637 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:03,508 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:03,613 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:04,412 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:04,803 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:05,529 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:05,655 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:06,529 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:06,678 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:07,350 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:07,632 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:08,514 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:08,638 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:09,448 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:09,556 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:10,334 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:10,673 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:11,513 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:11,641 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:12,312 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:12,408 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:13,125 INFO CLAW: Solution 1 computed for time t=5.000000
# Time step: 4.0 mins - uavg: 0.38688775601407543 - Elevation 0.24519223579658808
# Courant number: 0.15158694710040468
# 2019-05-10 23:09:13,468 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:14,199 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:14,297 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:15,058 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:15,183 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:15,982 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:16,275 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:17,132 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:17,231 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:18,014 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:18,116 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:18,944 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:19,260 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:20,037 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:20,181 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:20,935 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:21,060 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:21,745 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:21,973 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:22,731 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:22,831 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:23,728 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:23,848 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:24,857 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:25,213 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:26,353 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:26,510 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:27,361 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:27,457 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:28,167 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:28,438 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:29,164 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:29,316 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:30,049 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:30,159 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:30,875 INFO CLAW: Solution 1 computed for time t=5.000000
# Time step: 5.0 mins - uavg: 0.3866079778830532 - Elevation 0.24530214710344744
# Courant number: 0.16388902710665057
# 2019-05-10 23:09:31,147 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:31,964 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:32,080 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:32,810 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:32,947 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:33,830 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:34,088 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:34,825 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:34,936 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:35,636 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:35,707 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:36,409 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:36,674 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:37,662 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:37,786 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:38,849 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:38,982 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:39,906 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:40,349 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:41,172 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:41,268 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:42,054 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:42,152 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:42,780 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:43,092 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:43,835 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:43,980 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:44,716 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:44,831 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:45,722 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:46,040 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:46,765 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:46,905 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:47,648 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:47,745 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:48,509 INFO CLAW: Solution 1 computed for time t=5.000000
# Time step: 6.0 mins - uavg: 0.38639031872164337 - Elevation 0.2453657131693983
# Courant number: 0.13928161918234652
# 2019-05-10 23:09:48,867 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:49,675 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:49,824 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:50,498 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:50,593 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:51,360 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:51,548 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:52,231 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:52,327 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:53,063 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:53,198 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:53,928 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:54,302 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:55,033 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:55,124 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:55,891 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:56,002 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:56,735 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:56,999 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:57,710 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:57,858 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:58,803 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:09:58,986 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:09:59,957 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:00,306 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:01,281 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:01,421 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:02,359 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:02,486 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:03,098 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:03,385 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:04,075 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:04,183 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:04,902 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:05,019 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:05,813 INFO CLAW: Solution 1 computed for time t=5.000000
# Time step: 7.0 mins - uavg: 0.3861616787442209 - Elevation 0.24544937032562159
# Courant number: 0.2192172525199788
# 2019-05-10 23:10:06,088 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:06,950 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:07,107 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:07,976 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:08,067 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:08,780 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:09,064 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:09,763 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:09,866 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:10,643 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:10,748 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:11,629 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:11,896 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:12,599 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:12,694 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:13,564 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:13,677 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:14,503 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:14,911 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:15,618 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:15,790 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:16,499 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:16,611 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:17,317 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:17,520 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:18,213 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:18,301 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:19,016 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:19,177 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:19,964 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:20,313 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:21,051 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:21,141 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:21,833 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:21,955 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:22,728 INFO CLAW: Solution 1 computed for time t=5.000000
# Time step: 8.0 mins - uavg: 0.38590542019073837 - Elevation 0.24554765657911218
# Courant number: 0.14268210372762907
# 2019-05-10 23:10:23,052 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:23,902 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:24,015 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:24,792 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:24,897 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:25,585 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:25,825 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:26,466 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:26,576 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:27,333 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:27,419 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:28,156 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:28,556 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:29,329 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:29,416 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:30,162 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:30,265 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:30,886 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:31,080 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:31,792 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:31,895 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:32,657 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:32,890 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:34,223 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:34,724 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:35,632 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:35,758 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:36,605 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:36,762 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:37,874 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:38,143 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:39,069 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:39,193 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:40,023 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:40,117 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:40,828 INFO CLAW: Solution 1 computed for time t=5.000000
# Time step: 9.0 mins - uavg: 0.3856695803572741 - Elevation 0.2456342143649898
# Courant number: 0.1444940430690799
# 2019-05-10 23:10:41,105 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:41,952 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:42,040 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:42,784 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:42,923 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:43,676 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:43,913 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:44,687 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:44,811 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:45,680 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:45,798 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:46,618 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:46,860 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:47,634 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:47,756 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:48,512 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:48,610 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:49,345 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:49,640 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:50,497 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:50,628 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:51,408 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:51,526 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:52,466 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:52,749 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:53,687 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:53,784 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:54,582 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:54,673 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:55,286 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:55,569 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-10 23:10:56,289 INFO CLAW: Solution 1 computed for time t=5.000000
# 2019-05-10 23:10:56,381 INFO CLAW: Solution 0 computed for time t=0.000000
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-132-dd05bd86b226> in <module>
#     168     sws.set_Dirichlet_BC(hout,Qin)
#     169     sws.set_controller(tfinal=5., num_output_times=1)
# --> 170     sws.run()
#     171     cntrl = sws.get_controller()
#     172
#
# /pymorph/models/shallow_water_solver.py in run(self)
#     220         status = None
#     221         if self.controller != None and self.state!=None:
# --> 222             status = self.controller.run()
#     223         else:
#     224             raise ValueError('Model is not parameterized...')
#
# /clawpack/pyclaw/src/pyclaw/controller.py in run(self)
#     383                                             self.output_file_prefix,
#     384                                             self.write_aux_always,
# --> 385                                             self.output_options)
#     386             self.write_F()
#     387
#
# /clawpack/pyclaw/src/pyclaw/solution.py in write(self, frame, path, file_format, file_prefix, write_aux, options, write_p)
#     293             if file_prefix is None:
#     294                 write_func(self,frame,path,write_aux=write_aux,
# --> 295                             options=options,write_p=write_p)
#     296             else:
#     297                 write_func(self,frame,path,file_prefix=file_prefix,
#
# /clawpack/pyclaw/src/petclaw/fileio/petsc.py in write(solution, frame, path, file_prefix, write_aux, options, write_p)
#      92             state.gpVec.view(q_viewer)
#      93         else:
# ---> 94             state.gqVec.view(q_viewer)
#      95
#      96         if write_aux:
#
# PETSc/Vec.pyx in petsc4py.PETSc.Vec.view()
#
# Error: error code 16
# [0] VecView() line 590 in /tmp/pip-install-zpqu7s7y/petsc/src/vec/vec/interface/vector.c
# [0] VecView_MPI_DA() line 714 in /tmp/pip-install-zpqu7s7y/petsc/src/dm/impls/da/gr2.c
# [0] DMDAArrayMPIIO() line 614 in /tmp/pip-install-zpqu7s7y/petsc/src/dm/impls/da/gr2.c
# [0] PetscViewerBinaryWrite() line 942 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/impls/binary/binv.c
# [0] PetscViewerSetUp() line 337 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/interface/view.c
# [0] PetscViewerSetUp_Binary() line 1361 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/impls/binary/binv.c
# [0] PetscViewerFileSetUp_BinaryMPIIO() line 1295 in /tmp/pip-install-zpqu7s7y/petsc/src/sys/classes/viewer/impls/binary/binv.c

# %%
dune_height = np.zeros(len(tsteps))

tmArray = np.zeros(len(tsteps))
for i in range(0,len(tsteps)):
    zprofile = np.zeros(len(verts[i]))
    tmArray[i] = 6*i*dt/60.
    for j in range(0, len(verts[i])):
        zprofile[j] = verts[i][j][1]
    dune_height[i] = zprofile[100:400].max() - zprofile[100:400].min()

plt.plot(tmArray, dune_height)

# %%
simTime
# Out:
# 3600

# %%
len(tsteps)
# Out:
# 59

# %%
 i*dt
# Out:
# 580
