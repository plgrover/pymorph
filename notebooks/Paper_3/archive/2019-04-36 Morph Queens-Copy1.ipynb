# %%
# %matplotlib widget
import os,sys
import csv
import copy
import math
import collections
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from clawpack import pyclaw
from clawpack import riemann
import numpy as np
from scipy.integrate import simps, trapz
from scipy.interpolate import interp1d

sys.path.append("/pymorph")
from schemes.weno import get_left_flux,get_right_flux
from schemes.weno import get_stencil
import sediment_transport.sed_trans as sedtrans
import morph_geom_lib as mgl

from models.shallow_water_solver import shallow_water_solver
from schemes.avalanche_scheme import *

from matplotlib.collections import LineCollection
from mpl_toolkits.mplot3d import Axes3D

from IPython.display import display, Math, Latex


# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
plt.style.use(['dark_background'])

# %%
profile_folder = '/pymorph/notebooks/Paper_3/flume_profile_smoothed_v002.txt'
xc, z0 = mgl.readQueensFlume(profile_folder,1)
plt.plot(xc,z0)
zc = z0.copy()
# Out:
# Z: 87

# %%
#--------------------------------
# Set up the constants
#--------------------------------
nP=0.4
Slope = 1.26/1000 # Based on table 4.1 in Wiebe
mannings = 0.0248
beta = 0.01

# 32 cm Case 
Qc132 = 0.045
Qc120 = 0.020
B = 0.76
Qtotal32 = Qc132 * 3.
Qtotal20 = Qc120 * 3.
q32cm = Qtotal32 / B
q20cm = Qtotal20 / B

#sws.set_boundary_conditions()
hout = 0.357
Qin = q32cm

sws = shallow_water_solver(kernel_language='Fortran')
sws.set_solver(max_steps=100000)
sws.set_state_domain(xc,zc)
sws.set_mannings_source_term(mannings=mannings, slope=Slope)
sws.set_Dirichlet_BC(hout,Qin)
sws.set_inital_conditions(hout, 0.0)
sws.set_controller(tfinal=300., num_output_times=3)
sws.run()
cntrl = sws.get_controller()

h = sws.get_hf()
u = sws.get_uf()
q = sws.get_qf()


plt.plot(xc, h+zc)
plt.plot(xc,zc)

u = sws.get_uf()
h = sws.get_hf()
tau32 = np.zeros(nx)
for i in range(0,nx): #i=2
    tau32[i] = sedtrans.get_bed_shear(h[i],u[i],D50)
    
plt.plot(xc,tau32,'c-')

plt.plot(xc,zc,'r')
# Out:
# 2019-04-26 18:19:18,207 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:19:19,790 INFO CLAW: Solution 1 computed for time t=100.000000
# 2019-04-26 18:19:21,372 INFO CLAW: Solution 2 computed for time t=200.000000
# 2019-04-26 18:19:23,328 INFO CLAW: Solution 3 computed for time t=300.000000

# %%
#--------------------------------
# Set up the constants
#--------------------------------
nP=0.4
Slope = 1.26/1000 # Based on table 4.1 in Wiebe
mannings = 0.0248
beta = 0.01

# 32 cm Case 
Qc132 = 0.045
Qc120 = 0.020
B = 0.76
Qtotal32 = Qc132 * 3.
Qtotal20 = Qc120 * 3.
q32cm = Qtotal32 / B
q20cm = Qtotal20 / B

#sws.set_boundary_conditions()
hout = 0.237
Qin = q20cm

sws = shallow_water_solver(kernel_language='Fortran')
sws.set_solver(max_steps=100000)
sws.set_state_domain(xc,zc)
sws.set_mannings_source_term(mannings=mannings, slope=Slope)
sws.set_Dirichlet_BC(hout,Qin)
sws.set_inital_conditions(hout, 0.0)
sws.set_controller(tfinal=300., num_output_times=3)
sws.run()
cntrl = sws.get_controller()

h = sws.get_hf()
u = sws.get_uf()
q = sws.get_qf()


plt.plot(xc, h+zc)
plt.plot(xc,zc)

u = sws.get_uf()
h = sws.get_hf()
tau20 = np.zeros(nx)
for i in range(0,nx): #i=2
    tau20[i] = sedtrans.get_bed_shear(h[i],u[i],D50)
    
plt.plot(xc,tau32,'c-')
plt.plot(xc, tau20, 'g')

plt.plot(xc,zc,'r')
# Out:
# 2019-04-26 18:25:15,991 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:25:17,334 INFO CLAW: Solution 1 computed for time t=100.000000
# 2019-04-26 18:25:18,506 INFO CLAW: Solution 2 computed for time t=200.000000
# 2019-04-26 18:25:19,810 INFO CLAW: Solution 3 computed for time t=300.000000

# %%
plt.figure(figsize=(12, 4))
plt.plot(xc,tau32,'c-')
plt.plot(xc, tau20, 'g')

plt.plot(xc,zc,'r')

# %%
#--------------------------------
# Initialize the sed transport 
#--------------------------------    
# Eq 57
nx = len(xc)
qbedload = np.zeros(nx)
roe_speed = np.zeros(nx)
flux = np.zeros(nx)

# Sediment properties
D50 = 0.001     # Particle Diameter
rho_particule = 2650



#--------------------------------
#  Setup the model run parameters
#--------------------------------
simTime = 60*60 # Runtime in seconds
dt = 2 # Time step size (s)
nt = int(simTime/dt)  # Number of time steps

dx = sws.get_state().grid.delta[0]
#--------------------------------
# Set up the model reporting parameters

z0 = zc.copy() 
z600 = zc.copy() 
z2000 = zc.copy()
verts = []
extractionInterval = 60.*2
tsteps=[]
iterations = 0
cntr=0

#sws.set_boundary_conditions()
hout = 0.357
Qin = q32cm

sws = shallow_water_solver(kernel_language='Fortran')
sws.set_solver(max_steps=100000)
sws.set_state_domain(xc,zc)
sws.set_mannings_source_term(mannings=mannings, slope=Slope)
sws.set_boundary_conditions()
sws.set_inital_conditions(hout, 0.0)
sws.set_controller(tfinal=300., num_output_times=3)
sws.run()
cntrl = sws.get_controller()

h = sws.get_hf()
u = sws.get_uf()
q = sws.get_qf()
#--------------------------------
#  Run the model
#--------------------------------
for n in range(1,nt):  
    zn = zc.copy() 
    for i in range(0,nx): #i=2
        zloc = get_stencil(zn,i-2,i+4)        
        # Since k=3
        # stencil is i-2 to i+2 
        qloc = get_stencil(qbedload,i-2,i+4)
        if len(qloc)!=6:
            raise ValueError('Stencil is incorrect')
 
        # Determine the Upwind flux
        # The 0.5 comes from the c+abs(c) which is 2 if the wave speed is +ive
        # this is the evaluation of the left and right based fluxes. Eq. 18 and 19        
        if (zloc[3]-zloc[2]) == 0.0:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2]) )
        else:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2])/ (zloc[3]-zloc[2]) )
        
        if roe_speed[i] >= 0.0:
            flux[i] = get_left_flux(qloc)
        else:
            flux[i] = get_right_flux(qloc)
        
    # Need the sign of the phase speed
    # Need to check this out
    for i in range(0,nx): #i=2       
        floc = get_stencil(flux,i-1,i+1)
        zc[i] = zn[i]-(1./(1.-nP))*dt/dx*(floc[1]-floc[0])
    
    bed_max_delta = np.max(np.abs(zn - zc))
    
    # Apply the avalanche model
    zc, iterations1 = avalanche_model(dx,xc, zc, adjustment_angle=28.)
    # Now flip it to run in reverse
    zflip = np.flip(zc, axis=0)
    zflip, iterations1 = avalanche_model(dx,xc, zflip, adjustment_angle=28.)
    zc = np.flip(zflip, axis=0)
    
    #zc = z_updated.copy()
    
    # Re-run the solver and updated the sediment transport
    # Check if the avalanche model was updated OR the bed changed greater than the threshold
    #if iterations > 10 or bed_max_delta > 0.00005:
    iterations+=1
    if iterations > 2:        
        sws = shallow_water_solver(kernel_language='Fortran')
        sws.set_solver(max_steps=100000)
        sws.set_state_domain(xc,zc)
        sws.set_mannings_source_term(mannings=mannings, slope=1.26/1000.)
        sws.set_conditions_from_previous(h, q)
        sws.set_boundary_conditions()
        sws.set_controller(tfinal=20., num_output_times=1)
        sws.run()
        cntrl = sws.get_controller()      

        h = sws.get_hf()
        u = sws.get_uf()
        q = sws.get_qf()
        surf = h + zc
        
        iterations = 0
        
    slope = np.gradient(zc,dx)
    
    if 1==2:
        # ----------------------------------
        # Apply the two-step smooting scheme Eq. 6 in Niemann et al 2011.
        # ----------------------------------
        zhat = np.zeros(nx)
        for i in range(0, nx):  # i=2
            zlocal = get_stencil(zc, i - 1, i + 2)
            zhat[i] = 0.5*zlocal[1] + 0.25*(zlocal[0]+zlocal[2])

        for i in range(0, nx):
            zhatlocal = get_stencil(zhat, i - 1, i + 2)
            zc[i] = (3./2.)*zhatlocal[1] - 0.25*(zhatlocal[0]+zhatlocal[2])


    ## Nov 13 2018 - Can modify later
    for i in range(0,nx): #i=2        
        #zlocal = get_stencil(zc,i-2,i+2)
        #qbedload[i] = sedtrans.get_unit_bed_load2(h[i],u[i],D50,rho_particule,type='bagnold')
        qbedload[i] = sedtrans.get_unit_bed_load_slope(h[i],u[i],D50,slope[i], 
                                                       rho_particule, 
                                                       angleReposeDegrees = 30.0, 
                                                       type='bagnold',
                                                        useSlopeAdjust=False)

    
    if (n*dt / extractionInterval) == math.floor(n*dt / extractionInterval):
        verts.append(list(zip(xc.copy(),zc.copy())))
        tsteps.append(n*dt)        
        np.save('flume_dunes', verts)
    
    cntr += 1
    if cntr == extractionInterval:
        cntr = 0
        print('Time step {0} of {1} - bed_max_delta {2}'.format(n,nt,bed_max_delta))    
        
print('Done')
# Out:
# 2019-04-26 18:29:38,517 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:40,187 INFO CLAW: Solution 1 computed for time t=100.000000
# 2019-04-26 18:29:41,870 INFO CLAW: Solution 2 computed for time t=200.000000
# 2019-04-26 18:29:43,727 INFO CLAW: Solution 3 computed for time t=300.000000
# 2019-04-26 18:29:43,761 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:44,142 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:44,160 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:44,466 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:44,494 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:44,801 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:44,829 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:45,163 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:45,185 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:45,629 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:45,645 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:45,992 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:46,010 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:46,385 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:46,407 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:46,725 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:46,748 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:47,088 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:47,112 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:47,425 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:47,447 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:47,745 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:47,766 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:48,110 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:48,127 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:48,464 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:48,491 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:48,832 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29:48,849 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:29:49,209 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:29
INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:55,696 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:56,069 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:56,085 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:56,423 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:56,445 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:56,795 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:56,817 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:57,141 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:57,156 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:57,485 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:57,506 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:57,897 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:57,922 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:58,262 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:58,279 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:58,628 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:58,647 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:59,012 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:59,030 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:59,373 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:59,395 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:31:59,726 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:31:59,744 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:00,110 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:00,126 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:00,442 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:00,462 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:00,835 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:00,854 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:01,242 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:01,260 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:01,612 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:01,632 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:02,039 INFO CLAW: Solution 1 computed for time t=20.000000
# Time step 1080 of 1800 - bed_max_delta 8.720060397612861e-05
# 2019-04-26 18:32:02,078 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:02,447 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:02,470 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:02,857 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:02,877 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:03,256 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:03,274 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:03,707 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:03,729 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:04,246 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:04,269 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:04,652 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:04,676 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:04,993 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:05,010 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:05,410 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:05,432 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:05,838 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:05,856 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:06,220 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:06,243 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:06,608 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:06,626 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:06,943 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:06,962 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:07,286 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:07,302 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:07,671 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:07,695 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:08,102 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:08,123 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:08,488 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:08,515 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:08,860 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:08,880 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:09,209 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:09,227 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:09,609 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:09,627 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:09,963 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:09,982 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:10,865 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:10,949 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:11,612 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:11,638 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:12,105 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:12,121 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:12,479 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:12,501 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:12,868 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:12,887 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:13,347 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:13,377 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:13,732 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:13,757 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:14,102 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:14,137 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:14,543 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:14,561 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:14,927 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:14,959 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:15,319 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:15,343 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:15,765 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:15,784 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:16,130 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:16,154 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:16,565 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:16,586 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:16,955 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:16,976 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:17,378 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:17,395 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:17,770 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:17,795 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:18,176 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:18,195 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:18,644 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:18,664 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:19,087 INFO CLAW: Solution 1 computed for time t=20.000000
# Time step 1200 of 1800 - bed_max_delta 0.00010517487981515777
# 2019-04-26 18:32:19,118 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:19,459 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:19,478 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:19,837 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:19,865 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:20,343 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:20,374 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:20,843 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:20,869 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:21,303 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:21,330 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:21,713 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:21,734 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:22,141 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:22,162 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:22,501 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:22,525 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:22,893 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:22,912 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:23,306 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:23,327 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:23,705 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:23,729 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:24,137 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:24,155 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:24,481 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:24,508 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:24,872 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:24,897 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:25,263 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:25,281 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:25,675 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:25,696 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:26,062 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:26,085 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:32:26,445 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:32:26,463 INFO CLAW: Solution 0 computed for time t=0.000000

# %%
fig = plt.figure(figsize=(14, 6))
plt.plot(xc,surf)
plt.plot(xc,zc,'r')
plt.plot(xc,z0)

# %%
from matplotlib.collections import LineCollection
from mpl_toolkits.mplot3d import Axes3D




lines = LineCollection(verts)
fig = plt.figure(figsize=(18, 16))
ax = fig.gca(projection='3d')
lines.set_alpha(0.7)
ax.add_collection3d(lines, zs=tsteps, zdir='y')
ax.set_xlim3d(0, 2.6)
ax.set_zlim3d(-0.1, .2)
ax.set_ylim3d(0, 18000)
ax.set_zlabel('$z_b$')
ax.set_ylabel('$t(sec)$')
ax.set_xlabel('$x(m)$')

# %%
u = sws.get_uf()
h = sws.get_hf()
tau32 = np.zeros(nx)
for i in range(0,nx): #i=2
    tau32[i] = sedtrans.get_bed_shear(h[i],u[i],D50)
    
plt.plot(xc,tau32,'c-')

plt.plot(xc,zc,'r')
