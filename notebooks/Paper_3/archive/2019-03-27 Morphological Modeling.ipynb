# %%
import os,sys
import csv
import copy
import math
import collections

import matplotlib
import matplotlib.pyplot as plt
import clawpack.petclaw as pyclaw
from clawpack import riemann
import numpy as np
from scipy.integrate import simps, trapz
from scipy.interpolate import interp1d

sys.path.append("/pymorph")
from schemes.weno import get_left_flux,get_right_flux
from schemes.weno import get_stencil
import sediment_transport.sed_trans as sedtrans

from models.shallow_water_solver import shallow_water_solver
from schemes.avalanche_scheme import *

from matplotlib.collections import LineCollection
from mpl_toolkits.mplot3d import Axes3D

from IPython.display import display, Math, Latex

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

plt.style.use(['dark_background'])

# %%
#filepath = '/home/pgrover/working/working/Paper_4_Turbulence_Modelling/FlumeExperiment/geometries/flume_profile_smoothed.txt'
filepath = 'flume_profile_smoothed_v002.txt'

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
    
retval = collections.OrderedDict()


z = []
with open(filepath) as f:
    for line in f:
        values = line.split()
        if is_number(values[0])==False:
            if float(values[1]).is_integer():
                retval[values[0]]=int(values[1])
            else:
                retval[values[0]]=float(values[1])
        else:
            z.append(float(values[0]))
z = np.array(z)
print('Z: {0}'.format(len(z)))
xmax = float(retval['nrows']) * retval['cellsize']
nx = retval['nrows']
dx = retval['cellsize']

#--------------------------------
# Increase the resolution on the grid
#--------------------------------
resolution = 2
x = np.linspace(0, nx*dx, num=len(z))
f = interp1d(x, z)
xnew = np.linspace(0, nx*dx, num=len(z)*resolution)
znew = f(xnew)
nx = len(xnew)

print('Finished reinterpolating the grid nx={0}'.format(len(xnew)))
# Out:
# Z: 87
# Finished reinterpolating the grid nx=174

# %%
plt.plot(xnew,znew)

# %%
#--------------------------------
# Set up the constants
#--------------------------------
a=0.001
b=3.0
Q=10.0
nP=0.4
Slope = 1.0/792.0
mannings = 0.022
water_surface= 0.32      # Surface water elevation
beta = 0.01

# Sediment properties
D50 = 0.001     # Particle Diameter
rho_particule = 2650

#--------------------------------
# Set up the domain, BCs and ICs
#--------------------------------
import logging
logger = logging.getLogger('pyclaw')
logger.setLevel(logging.CRITICAL)

x = pyclaw.Dimension(0.0,xmax,len(xnew),name='x')
domain = pyclaw.Domain(x)
state = pyclaw.State(domain,1)
xc = state.grid.x.centers
dx = state.grid.delta[0]
print('Grid dx = {0}'.format(dx))
print('Grid nx = {0}'.format(len(xc)))

zc = znew.copy()
z_hydro = znew.copy()

 # Gravitational constant
state.problem_data['grav'] = 9.8
state.problem_data['sea_level'] = 0.0


# Set up the inital state of the flow
shw_slvr = shallow_solver(domain, slope=Slope, mannings=mannings)
u, surf,h = shw_slvr.run(zc,water_surface,3000)


if np.isnan(u).any():
    # Get the flow
    print( u)
    raise ValueError('Failed to calculate the flow')
# Out:
# Grid dx = 0.015
# Grid nx = 174
# 2019-04-09 17:46:34,661 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:46:42,135 INFO CLAW: Solution 1 computed for time t=65.561031

# %%
fig = plt.figure(figsize=(12, 4))
plt.plot(xc,surf)
plt.plot(xc,zc,'r')

# %%
fig = plt.figure(figsize=(12, 4))
plt.plot(xc,u)
plt.ylabel('$u$ (m/s)')
# Out:
# Text(0, 0.5, '$u$ (m/s)')

# %%
u.mean()
# Out:
# 0.5628329873987873

# %%
#--------------------------------
# Initialize the sed transport 
#--------------------------------    
# Eq 57
qbedload = np.zeros(nx)
roe_speed = np.zeros(nx)
qbedload = a*u**b
flux = np.zeros(nx)

#--------------------------------
#  Setup the model run parameters
#--------------------------------
simTime = 600. # Runtime in seconds
dt = 1 # Time step size (s)
nt = int(simTime/dt)  # Number of time steps


#--------------------------------
# Set up the model reporting parameters
#--------------------------------
z0 = zc.copy() 
z600 = zc.copy() 
z2000 = zc.copy()
verts = []
extractionInterval = 5.
tsteps=[]
iterations = 0
cntr=0
#--------------------------------
#  Run the model
#--------------------------------
for n in range(1,nt):  
    zn = zc.copy() 
    for i in range(0,nx): #i=2
        zloc = get_stencil(zn,i-2,i+4)        
        # Since k=3
        # stencil is i-2 to i+2 
        qloc = get_stencil(qbedload,i-2,i+4)
        if len(qloc)!=6:
            raise ValueError('Stencil is incorrect')
 
        # Determine the Upwind flux
        # The 0.5 comes from the c+abs(c) which is 2 if the wave speed is +ive
        # this is the evaluation of the left and right based fluxes. Eq. 18 and 19        
        if (zloc[3]-zloc[2]) == 0.0:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2]) )
        else:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2])/ (zloc[3]-zloc[2]) )
        
        if roe_speed[i] >= 0.0:
            flux[i] = get_left_flux(qloc)
        else:
            flux[i] = get_right_flux(qloc)
        
    # Need the sign of the phase speed
    # Need to check this out
    for i in range(0,nx): #i=2       
        floc = get_stencil(flux,i-1,i+1)
        zc[i] = zn[i]-(1./(1.-nP))*dt/dx*(floc[1]-floc[0])
    
    bed_max_delta = np.max(np.abs(zn - zc))
    
    # Apply the avalanche model
    zc, iterations1 = avalanche_model(dx,xc, zc, adjustment_angle=28.)
    # Now flip it to run in reverse
    zflip = np.flip(zc, axis=0)
    zflip, iterations1 = avalanche_model(dx,xc, zflip, adjustment_angle=28.)
    zc = np.flip(zflip, axis=0)
    
    #zc = z_updated.copy()
    
    # Re-run the solver and updated the sediment transport
    # Check if the avalanche model was updated OR the bed changed greater than the threshold
    #if iterations > 10 or bed_max_delta > 0.00005:
    iterations+=1
    if iterations > 4:
        u, surf,h = shw_slvr.run(zc,water_surface, 120)
        iterations = 0
        #print('Updated')
        # Remove the old method 
        #qbedload = a*u**b
    slope = np.gradient(zc,dx)
    
    ## Nov 13 2018 - Can modify later
    for i in range(0,nx): #i=2        
        #zlocal = get_stencil(zc,i-2,i+2)
        #qbedload[i] = sedtrans.get_unit_bed_load2(h[i],u[i],D50,rho_particule,type='bagnold')
        qbedload[i] = sedtrans.get_unit_bed_load_slope(h[i],u[i],D50,slope[i], 
                                                       rho_particule, 
                                                       angleReposeDegrees = 30.0, 
                                                       type='mpm',
                                                        useSlopeAdjust=True)

    
    if (n*dt / extractionInterval) == math.floor(n*dt / extractionInterval):
        verts.append(list(zip(xc.copy(),zc.copy())))
        tsteps.append(n*dt)        
        np.save('flume_dunes', verts)
    
    cntr += 1
    if cntr == extractionInterval:
        cntr = 0
        print('Time step {0} of {1} - bed_max_delta {2}'.format(n,nt,bed_max_delta))    
        
print('Done')
# Out:
# 2019-04-09 17:46:42,852 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:46:50,242 INFO CLAW: Solution 1 computed for time t=65.567682
# Time step 5 of 600 - bed_max_delta 0.00043967510594368486
# 2019-04-09 17:46:50,293 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:46:57,754 INFO CLAW: Solution 1 computed for time t=65.574547
# Time step 10 of 600 - bed_max_delta 0.0002975516956509744
# 2019-04-09 17:46:57,800 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:47:05,287 INFO CLAW: Solution 1 computed for time t=65.579088
# Time step 15 of 600 - bed_max_delta 0.0002215837565609953
# 2019-04-09 17:47:05,332 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:47:12,712 INFO CLAW: Solution 1 computed for time t=65.586898
# Time step 20 of 600 - bed_max_delta 0.0002018611095653093
# 2019-04-09 17:47:12,755 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:47:20,237 INFO CLAW: Solution 1 computed for time t=65.590711
# Time step 25 of 600 - bed_max_delta 0.0001893285202751345
# 2019-04-09 17:47:20,283 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:47:27,877 INFO CLAW: Solution 1 computed for time t=65.595320
# Time step 30 of 600 - bed_max_delta 0.00018070076054540682
# 2019-04-09 17:47:27,925 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:47:35,312 INFO CLAW: Solution 1 computed for time t=65.601975
# Time step 35 of 600 - bed_max_delta 0.0001742644691485641
# 2019-04-09 17:47:35,357 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:47:42,815 INFO CLAW: Solution 1 computed for time t=65.610467
# Time step 40 of 600 - bed_max_delta 0.00016905415624432485
# 2019-04-09 17:47:42,860 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:47:50,289 INFO CLAW: Solution 1 computed for time t=65.614302
# Time step 45 of 600 - bed_max_delta 0.0001645127350104747
# 2019-04-09 17:47:50,336 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:47:57,932 INFO CLAW: Solution 1 computed for time t=65.619420
# Time step 50 of 600 - bed_max_delta 0.00016030502647252157
# 2019-04-09 17:47:57,974 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:48:05,657 INFO CLAW: Solution 1 computed for time t=65.625877
# Time step 55 of 600 - bed_max_delta 0.00015627871920305403
# 2019-04-09 17:48:05,703 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:48:13,104 INFO CLAW: Solution 1 computed for time t=65.633672
# Time step 60 of 600 - bed_max_delta 0.00015234949409997575
# 2019-04-09 17:48:13,153 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:48:20,598 INFO CLAW: Solution 1 computed for time t=65.641136
# Time step 65 of 600 - bed_max_delta 0.0001484820427240796
# 2019-04-09 17:48:20,644 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:48:27,961 INFO CLAW: Solution 1 computed for time t=65.645854
# Time step 70 of 600 - bed_max_delta 0.0001446630006547503
# 2019-04-09 17:48:28,006 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:48:35,564 INFO CLAW: Solution 1 computed for time t=65.651518
# Time step 75 of 600 - bed_max_delta 0.00014089241930156926
# 2019-04-09 17:48:35,611 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:48:43,169 INFO CLAW: Solution 1 computed for time t=65.658137
# Time step 80 of 600 - bed_max_delta 0.0001375634283706656
# 2019-04-09 17:48:43,211 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:48:50,617 INFO CLAW: Solution 1 computed for time t=65.665701
# Time step 85 of 600 - bed_max_delta 0.00013467571551348256
# 2019-04-09 17:48:50,662 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:48:58,140 INFO CLAW: Solution 1 computed for time t=65.674187
# Time step 90 of 600 - bed_max_delta 0.00013182410747420922
# 2019-04-09 17:48:58,186 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:49:05,833 INFO CLAW: Solution 1 computed for time t=65.681181
# Time step 95 of 600 - bed_max_delta 0.00012901280591085668
# 2019-04-09 17:49:05,880 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:49:13,514 INFO CLAW: Solution 1 computed for time t=65.686505
# Time step 100 of 600 - bed_max_delta 0.00012624266032977907
# 2019-04-09 17:49:13,562 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:49:21,237 INFO CLAW: Solution 1 computed for time t=65.692563
# Time step 105 of 600 - bed_max_delta 0.000123519435954067
# 2019-04-09 17:49:21,289 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:49:28,815 INFO CLAW: Solution 1 computed for time t=65.699347
# Time step 110 of 600 - bed_max_delta 0.00012085125734301663
# 2019-04-09 17:49:28,882 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:49:39,997 INFO CLAW: Solution 1 computed for time t=65.706843
# Time step 115 of 600 - bed_max_delta 0.00011824160757252511
# 2019-04-09 17:49:40,107 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:49:52,383 INFO CLAW: Solution 1 computed for time t=65.715029
# Time step 120 of 600 - bed_max_delta 0.00011569324662437375
# 2019-04-09 17:49:52,430 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:50:02,377 INFO CLAW: Solution 1 computed for time t=65.723417
# Time step 125 of 600 - bed_max_delta 0.0001136587279939906
# 2019-04-09 17:50:02,419 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:50:10,138 INFO CLAW: Solution 1 computed for time t=65.728786
# Time step 130 of 600 - bed_max_delta 0.00011173924209979813
# 2019-04-09 17:50:10,185 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:50:17,664 INFO CLAW: Solution 1 computed for time t=65.734718
# Time step 135 of 600 - bed_max_delta 0.00010983637202360494
# 2019-04-09 17:50:17,710 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:50:25,052 INFO CLAW: Solution 1 computed for time t=65.741209
# Time step 140 of 600 - bed_max_delta 0.000107958328937615
# 2019-04-09 17:50:25,099 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:50:32,603 INFO CLAW: Solution 1 computed for time t=65.748247
# Time step 145 of 600 - bed_max_delta 0.00010610799098970808
# 2019-04-09 17:50:32,647 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:50:40,464 INFO CLAW: Solution 1 computed for time t=65.755819
# Time step 150 of 600 - bed_max_delta 0.00010428759990899206
# 2019-04-09 17:50:40,529 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:50:48,041 INFO CLAW: Solution 1 computed for time t=65.763909
# Time step 155 of 600 - bed_max_delta 0.00010249878808090904
# 2019-04-09 17:50:48,090 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:50:55,884 INFO CLAW: Solution 1 computed for time t=65.772499
# Time step 160 of 600 - bed_max_delta 0.00010074280074990824
# 2019-04-09 17:50:55,932 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:51:04,295 INFO CLAW: Solution 1 computed for time t=65.778340
# Time step 165 of 600 - bed_max_delta 9.902042981817585e-05
# 2019-04-09 17:51:04,350 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:51:12,399 INFO CLAW: Solution 1 computed for time t=65.784212
# Time step 170 of 600 - bed_max_delta 9.749008665196554e-05
# 2019-04-09 17:51:12,442 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:51:20,163 INFO CLAW: Solution 1 computed for time t=65.790534
# Time step 175 of 600 - bed_max_delta 9.617638039495502e-05
# 2019-04-09 17:51:20,218 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:51:27,690 INFO CLAW: Solution 1 computed for time t=65.797297
# Time step 180 of 600 - bed_max_delta 9.487216183762248e-05
# 2019-04-09 17:51:27,736 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:51:35,155 INFO CLAW: Solution 1 computed for time t=65.804487
# Time step 185 of 600 - bed_max_delta 9.357908548807137e-05
# 2019-04-09 17:51:35,203 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:51:42,855 INFO CLAW: Solution 1 computed for time t=65.812092
# Time step 190 of 600 - bed_max_delta 9.22986500793456e-05
# 2019-04-09 17:51:42,905 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:51:50,313 INFO CLAW: Solution 1 computed for time t=65.820098
# Time step 195 of 600 - bed_max_delta 9.103203331867898e-05
# 2019-04-09 17:51:50,361 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:51:57,978 INFO CLAW: Solution 1 computed for time t=65.827542
# Time step 200 of 600 - bed_max_delta 8.978025939464923e-05
# 2019-04-09 17:51:58,024 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:52:05,765 INFO CLAW: Solution 1 computed for time t=65.833154
# Time step 205 of 600 - bed_max_delta 8.854267769093857e-05
# 2019-04-09 17:52:05,819 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:52:13,273 INFO CLAW: Solution 1 computed for time t=65.839125
# Time step 210 of 600 - bed_max_delta 8.731797578989328e-05
# 2019-04-09 17:52:13,324 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:52:20,772 INFO CLAW: Solution 1 computed for time t=65.845450
# Time step 215 of 600 - bed_max_delta 8.611050823671695e-05
# 2019-04-09 17:52:20,819 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:52:28,371 INFO CLAW: Solution 1 computed for time t=65.852120
# Time step 220 of 600 - bed_max_delta 8.503847235084502e-05
# 2019-04-09 17:52:28,419 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:52:36,047 INFO CLAW: Solution 1 computed for time t=65.859128
# Time step 225 of 600 - bed_max_delta 8.410668747037275e-05
# 2019-04-09 17:52:36,095 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:52:43,446 INFO CLAW: Solution 1 computed for time t=65.866464
# Time step 230 of 600 - bed_max_delta 8.317799023201122e-05
# 2019-04-09 17:52:43,501 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:52:51,131 INFO CLAW: Solution 1 computed for time t=65.874118
# Time step 235 of 600 - bed_max_delta 8.225343908905072e-05
# 2019-04-09 17:52:51,180 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:52:59,112 INFO CLAW: Solution 1 computed for time t=65.881912
# Time step 240 of 600 - bed_max_delta 8.133400941524871e-05
# 2019-04-09 17:52:59,159 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:53:09,022 INFO CLAW: Solution 1 computed for time t=65.887367
# Time step 245 of 600 - bed_max_delta 8.042024026271022e-05
# 2019-04-09 17:53:09,064 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:53:17,611 INFO CLAW: Solution 1 computed for time t=65.893115
# Time step 250 of 600 - bed_max_delta 7.950906825570508e-05
# 2019-04-09 17:53:17,650 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:53:25,659 INFO CLAW: Solution 1 computed for time t=65.899160
# Time step 255 of 600 - bed_max_delta 7.860484987733812e-05
# 2019-04-09 17:53:25,701 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:53:33,835 INFO CLAW: Solution 1 computed for time t=65.905493
# Time step 260 of 600 - bed_max_delta 7.770806240182254e-05
# 2019-04-09 17:53:33,880 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:53:41,922 INFO CLAW: Solution 1 computed for time t=65.912107
# Time step 265 of 600 - bed_max_delta 7.681947111216197e-05
# 2019-04-09 17:53:41,962 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:53:51,955 INFO CLAW: Solution 1 computed for time t=65.918995
# Time step 270 of 600 - bed_max_delta 7.593931314432353e-05
# 2019-04-09 17:53:52,017 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:54:02,392 INFO CLAW: Solution 1 computed for time t=65.926149
# Time step 275 of 600 - bed_max_delta 7.515217734785709e-05
# 2019-04-09 17:54:02,436 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:54:12,802 INFO CLAW: Solution 1 computed for time t=65.933560
# Time step 280 of 600 - bed_max_delta 7.446460163125501e-05
# 2019-04-09 17:54:12,856 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:54:23,043 INFO CLAW: Solution 1 computed for time t=65.939774
# Time step 285 of 600 - bed_max_delta 7.377723499014943e-05
# 2019-04-09 17:54:23,091 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:54:33,226 INFO CLAW: Solution 1 computed for time t=65.945229
# Time step 290 of 600 - bed_max_delta 7.308864631308878e-05
# 2019-04-09 17:54:33,277 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:54:43,689 INFO CLAW: Solution 1 computed for time t=65.950927
# Time step 295 of 600 - bed_max_delta 7.239997096621098e-05
# 2019-04-09 17:54:43,739 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:54:51,752 INFO CLAW: Solution 1 computed for time t=65.956864
# Time step 300 of 600 - bed_max_delta 7.171318182661382e-05
# 2019-04-09 17:54:51,792 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:55:00,038 INFO CLAW: Solution 1 computed for time t=65.963035
# Time step 305 of 600 - bed_max_delta 7.1028663995297e-05
# 2019-04-09 17:55:00,075 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:55:08,765 INFO CLAW: Solution 1 computed for time t=65.969435
# Time step 310 of 600 - bed_max_delta 7.034708389178426e-05
# 2019-04-09 17:55:08,802 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:55:17,875 INFO CLAW: Solution 1 computed for time t=65.976059
# Time step 315 of 600 - bed_max_delta 6.966870833982619e-05
# 2019-04-09 17:55:17,993 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:55:27,609 INFO CLAW: Solution 1 computed for time t=65.982902
# Time step 320 of 600 - bed_max_delta 6.899372913426322e-05
# 2019-04-09 17:55:27,646 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:55:35,668 INFO CLAW: Solution 1 computed for time t=65.989957
# Time step 325 of 600 - bed_max_delta 6.83222630138286e-05
# 2019-04-09 17:55:35,709 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:55:45,389 INFO CLAW: Solution 1 computed for time t=65.995968
# Time step 330 of 600 - bed_max_delta 6.765684533804536e-05
# 2019-04-09 17:55:45,430 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:55:55,849 INFO CLAW: Solution 1 computed for time t=66.001230
# Time step 335 of 600 - bed_max_delta 6.71282922347742e-05
# 2019-04-09 17:55:55,890 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:56:05,620 INFO CLAW: Solution 1 computed for time t=66.006703
# Time step 340 of 600 - bed_max_delta 6.659674478083633e-05
# 2019-04-09 17:56:05,712 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:56:14,915 INFO CLAW: Solution 1 computed for time t=66.012381
# Time step 345 of 600 - bed_max_delta 6.606426147013136e-05
# 2019-04-09 17:56:14,956 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:56:23,626 INFO CLAW: Solution 1 computed for time t=66.018260
# Time step 350 of 600 - bed_max_delta 6.553115202057383e-05
# 2019-04-09 17:56:23,670 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:56:33,011 INFO CLAW: Solution 1 computed for time t=66.024335
# Time step 355 of 600 - bed_max_delta 6.49977166510031e-05
# 2019-04-09 17:56:33,054 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:56:42,330 INFO CLAW: Solution 1 computed for time t=66.030601
# Time step 360 of 600 - bed_max_delta 6.446448887065942e-05
# 2019-04-09 17:56:42,371 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:56:50,751 INFO CLAW: Solution 1 computed for time t=66.037054
# Time step 365 of 600 - bed_max_delta 6.393183187186624e-05
# 2019-04-09 17:56:50,794 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:57:00,555 INFO CLAW: Solution 1 computed for time t=66.043688
# Time step 370 of 600 - bed_max_delta 6.3399758291071e-05
# 2019-04-09 17:57:00,604 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:57:09,385 INFO CLAW: Solution 1 computed for time t=66.049701
# Time step 375 of 600 - bed_max_delta 6.286841345041344e-05
# 2019-04-09 17:57:09,435 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:57:17,432 INFO CLAW: Solution 1 computed for time t=66.054742
# Time step 380 of 600 - bed_max_delta 6.233659032990266e-05
# 2019-04-09 17:57:17,477 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:57:25,612 INFO CLAW: Solution 1 computed for time t=66.059957
# Time step 385 of 600 - bed_max_delta 6.180395422077101e-05
# 2019-04-09 17:57:25,654 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:57:34,995 INFO CLAW: Solution 1 computed for time t=66.065346
# Time step 390 of 600 - bed_max_delta 6.127258857516887e-05
# 2019-04-09 17:57:35,117 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:57:44,713 INFO CLAW: Solution 1 computed for time t=66.070905
# Time step 395 of 600 - bed_max_delta 6.082854461791909e-05
# 2019-04-09 17:57:44,765 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:57:53,790 INFO CLAW: Solution 1 computed for time t=66.076630
# Time step 400 of 600 - bed_max_delta 6.0405991553207083e-05
# 2019-04-09 17:57:53,831 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:58:01,659 INFO CLAW: Solution 1 computed for time t=66.082519
# Time step 405 of 600 - bed_max_delta 5.9981680050846115e-05
# 2019-04-09 17:58:01,708 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:58:09,704 INFO CLAW: Solution 1 computed for time t=66.088569
# Time step 410 of 600 - bed_max_delta 5.9555766514823166e-05
# 2019-04-09 17:58:09,748 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:58:17,541 INFO CLAW: Solution 1 computed for time t=66.094776
# Time step 415 of 600 - bed_max_delta 5.912847248319003e-05
# 2019-04-09 17:58:17,593 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:58:26,521 INFO CLAW: Solution 1 computed for time t=66.101136
# Time step 420 of 600 - bed_max_delta 5.8699971546678775e-05
# 2019-04-09 17:58:26,568 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:58:34,984 INFO CLAW: Solution 1 computed for time t=66.106272
# Time step 425 of 600 - bed_max_delta 5.8270432313260734e-05
# 2019-04-09 17:58:35,028 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:58:43,486 INFO CLAW: Solution 1 computed for time t=66.111167
# Time step 430 of 600 - bed_max_delta 5.78380458736219e-05
# 2019-04-09 17:58:43,549 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:58:54,500 INFO CLAW: Solution 1 computed for time t=66.116217
# Time step 435 of 600 - bed_max_delta 5.740462533261256e-05
# 2019-04-09 17:58:54,541 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:59:02,521 INFO CLAW: Solution 1 computed for time t=66.121418
# Time step 440 of 600 - bed_max_delta 5.6970748084122363e-05
# 2019-04-09 17:59:02,576 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:59:11,298 INFO CLAW: Solution 1 computed for time t=66.126768
# Time step 445 of 600 - bed_max_delta 5.6536465286177034e-05
# 2019-04-09 17:59:11,361 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:59:22,057 INFO CLAW: Solution 1 computed for time t=66.132262
# Time step 450 of 600 - bed_max_delta 5.61018773759768e-05
# 2019-04-09 17:59:22,099 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:59:30,243 INFO CLAW: Solution 1 computed for time t=66.137899
# Time step 455 of 600 - bed_max_delta 5.570843851475035e-05
# 2019-04-09 17:59:30,283 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:59:37,952 INFO CLAW: Solution 1 computed for time t=66.143675
# Time step 460 of 600 - bed_max_delta 5.536192190997227e-05
# 2019-04-09 17:59:37,995 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:59:49,465 INFO CLAW: Solution 1 computed for time t=66.149588
# Time step 465 of 600 - bed_max_delta 5.501293043308139e-05
# 2019-04-09 17:59:49,517 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 17:59:59,784 INFO CLAW: Solution 1 computed for time t=66.155494
# Time step 470 of 600 - bed_max_delta 5.466166716805096e-05
# 2019-04-09 17:59:59,827 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:00:07,789 INFO CLAW: Solution 1 computed for time t=66.160100
# Time step 475 of 600 - bed_max_delta 5.430813106153953e-05
# 2019-04-09 18:00:07,828 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:00:15,806 INFO CLAW: Solution 1 computed for time t=66.164829
# Time step 480 of 600 - bed_max_delta 5.395093663270595e-05
# 2019-04-09 18:00:15,849 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:00:24,575 INFO CLAW: Solution 1 computed for time t=66.169690
# Time step 485 of 600 - bed_max_delta 5.359202883331582e-05
# 2019-04-09 18:00:24,621 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:00:32,665 INFO CLAW: Solution 1 computed for time t=66.174679
# Time step 490 of 600 - bed_max_delta 5.3231610669550455e-05
# 2019-04-09 18:00:32,716 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:00:41,770 INFO CLAW: Solution 1 computed for time t=66.179797
# Time step 495 of 600 - bed_max_delta 5.2869720476043935e-05
# 2019-04-09 18:00:41,818 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:00:50,738 INFO CLAW: Solution 1 computed for time t=66.185040
# Time step 500 of 600 - bed_max_delta 5.2506526742823745e-05
# 2019-04-09 18:00:50,791 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:00:58,696 INFO CLAW: Solution 1 computed for time t=66.190406
# Time step 505 of 600 - bed_max_delta 5.214221812569614e-05
# 2019-04-09 18:00:58,737 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:01:07,352 INFO CLAW: Solution 1 computed for time t=66.195894
# Time step 510 of 600 - bed_max_delta 5.1776967584332007e-05
# 2019-04-09 18:01:07,395 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:01:15,185 INFO CLAW: Solution 1 computed for time t=66.201500
# Time step 515 of 600 - bed_max_delta 5.141083330600926e-05
# 2019-04-09 18:01:15,223 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:01:22,689 INFO CLAW: Solution 1 computed for time t=66.207185
# Time step 520 of 600 - bed_max_delta 5.109073782233464e-05
# 2019-04-09 18:01:22,731 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:01:30,419 INFO CLAW: Solution 1 computed for time t=66.211640
# Time step 525 of 600 - bed_max_delta 5.079728968738345e-05
# 2019-04-09 18:01:30,463 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:01:38,276 INFO CLAW: Solution 1 computed for time t=66.216147
# Time step 530 of 600 - bed_max_delta 5.0500155590150336e-05
# 2019-04-09 18:01:38,317 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:01:45,916 INFO CLAW: Solution 1 computed for time t=66.220773
# Time step 535 of 600 - bed_max_delta 5.020068842452596e-05
# 2019-04-09 18:01:45,959 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:01:54,861 INFO CLAW: Solution 1 computed for time t=66.225515
# Time step 540 of 600 - bed_max_delta 4.9899063244200625e-05
# 2019-04-09 18:01:54,921 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:02:04,854 INFO CLAW: Solution 1 computed for time t=66.230371
# Time step 545 of 600 - bed_max_delta 4.959547366290007e-05
# 2019-04-09 18:02:04,907 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:02:13,771 INFO CLAW: Solution 1 computed for time t=66.235339
# Time step 550 of 600 - bed_max_delta 4.929008939384347e-05
# 2019-04-09 18:02:13,834 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:02:21,923 INFO CLAW: Solution 1 computed for time t=66.240417
# Time step 555 of 600 - bed_max_delta 4.898306557181778e-05
# 2019-04-09 18:02:21,965 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:02:29,816 INFO CLAW: Solution 1 computed for time t=66.245603
# Time step 560 of 600 - bed_max_delta 4.867456498738182e-05
# 2019-04-09 18:02:29,879 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:02:37,640 INFO CLAW: Solution 1 computed for time t=66.250894
# Time step 565 of 600 - bed_max_delta 4.836469112926706e-05
# 2019-04-09 18:02:37,694 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:02:46,418 INFO CLAW: Solution 1 computed for time t=66.256288
# Time step 570 of 600 - bed_max_delta 4.8053563232189345e-05
# 2019-04-09 18:02:46,474 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:02:54,975 INFO CLAW: Solution 1 computed for time t=66.260649
# Time step 575 of 600 - bed_max_delta 4.774128090884178e-05
# 2019-04-09 18:02:55,015 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:03:02,654 INFO CLAW: Solution 1 computed for time t=66.264942
# Time step 580 of 600 - bed_max_delta 4.7426911148073375e-05
# 2019-04-09 18:03:02,695 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:03:11,458 INFO CLAW: Solution 1 computed for time t=66.269337
# Time step 585 of 600 - bed_max_delta 4.7163529405525734e-05
# 2019-04-09 18:03:11,527 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:03:19,359 INFO CLAW: Solution 1 computed for time t=66.273834
# Time step 590 of 600 - bed_max_delta 4.691034274994371e-05
# 2019-04-09 18:03:19,401 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 18:03:27,119 INFO CLAW: Solution 1 computed for time t=66.278432
# Time step 595 of 600 - bed_max_delta 4.665489529030384e-05
# Done

# %%
fig = plt.figure(figsize=(12, 4))
plt.plot(xc,surf)
plt.plot(xc,znew,'g.')
plt.plot(xc,zc,'r')

# %%
fig = plt.figure(figsize=(12, 4))
plt.plot(xc,u)
plt.ylabel('u (m/s)')
# Out:
# Text(0, 0.5, 'u (m/s)')

# %%
tau = np.zeros(nx)
for i in range(0,nx): #i=2
    tau[i] = sedtrans.get_bed_shear(h[i],u[i],D50)
    
tau_cr = sedtrans.get_critical_shear(D50, rho_particule)
fig = plt.figure(figsize=(12, 4))
plt.axhline(tau_cr)
plt.plot(xc,tau)
plt.ylabel('$\\tau$')
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
from matplotlib.collections import LineCollection
from mpl_toolkits.mplot3d import Axes3D




lines = LineCollection(verts)
fig = plt.figure(figsize=(18, 16))
ax = fig.gca(projection='3d')
lines.set_alpha(0.7)
ax.add_collection3d(lines, zs=tsteps, zdir='y')
ax.set_xlim3d(0, 2.6)
ax.set_zlim3d(0, .2)
ax.set_ylim3d(0, 600)
ax.set_zlabel('$z_b$')
ax.set_ylabel('$t(sec)$')
ax.set_xlabel('$x(m)$')
# Out:
# Text(0.5, 0, '$x(m)$')
