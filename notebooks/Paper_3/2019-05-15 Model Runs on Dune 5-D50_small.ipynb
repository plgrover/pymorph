# %%
# %matplotlib widget
import os,sys
import csv
import copy
import math
import collections
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from clawpack import pyclaw
from clawpack import riemann
from IPython.display import HTML
import numpy as np
from scipy.integrate import simps, trapz
from scipy.interpolate import interp1d
from scipy import signal
sys.path.append("/pymorph")

import morph_geom_lib as mgl
import models.shallow_depth_morph_models as sdmodels
import schemes.avalanche_scheme 


from matplotlib.collections import LineCollection
from mpl_toolkits.mplot3d import Axes3D

from IPython.display import display, Math, Latex
from matplotlib import animation, rc

import schemes.weno as weno
import sediment_transport.sed_trans as sedtrans
from schemes.avalanche_scheme import avalanche_model, get_slope
from models.shallow_water_solver import shallow_water_solver

rc('animation', html='html5')

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#plt.style.use(['dark_background'])

# %%
filepath = 'dune_profile_dune5_repeated.txt'

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
    


def readFile(filepath, resolution_cells = 800):
    xs = []
    zs = []
    with open(filepath) as f:
        for line in f:
            values = line.split(',')
            if is_number(values[0]) and is_number(values[1]):
                x = float(values[0])
                z = float(values[1])
                xs.append(x)
                zs.append(z)
                
    xs = np.array(xs)
    zs = np.array(zs)
    
    #--------------------------------
    # Increase the resolution on the grid
    #--------------------------------
    xmax = xs.max()
    nx = len(xs)
    f = interp1d(xs, zs)
    
    xnew = np.linspace(0., xmax, num=resolution_cells)
    znew = f(xnew)
    return xnew, znew

x0,z0 = readFile(filepath, resolution_cells = 800)

dx = x0[1] - x0[0]

print('dx: {0} cm'.format(dx*100.))
print('nx {0}'.format(len(x0)))

fig = plt.figure(figsize=(14, 4))
plt.plot(x0,z0, '.')
plt.xlabel('x (m)')
plt.ylabel('z (m)')
# Out:
# dx: 0.9762202753441801 cm
# nx 800
# Text(0, 0.5, 'z (m)')

# %% [markdown]
# # Model Runs for Paper
#
# - Equilibrium vs non-Equlibrium
# - Shallow water vs simple flow model
# - modified Ycr (+20%, -20%)
# - other models (Euler, Upwinding, MacCormick)

# %%
#--------------------------------
# Set up the bed properties
#--------------------------------
D50 = 0.0008
repose_angle = 30.
rho_particle = 2650.
nP = 0.4

#--------------------------------
# Set up the Boundary conditions
#--------------------------------
# 32 cm Case 
Qc132 = 0.0455
Qc120 = 0.020
B = 0.76
Qtotal32 = Qc132 * 3.
Qtotal20 = Qc120 * 3.
q32cm = Qtotal32 / B
q20cm = Qtotal20 / B

sOut32 = 0.357
sOut20 = 0.237

#--------------------------------
# Set up the Flow Proerties
#--------------------------------
mannings_n = 0.024
bed_slope = 1.26/1000.
ks=0.002

#--------------------------------
#  Setup the model run parameters
#--------------------------------
simTime = 300*60       # Runtime in seconds
dt = 5                # Time step size (s)
nt = int(simTime/dt)  # Number of time steps
extractionTime = 60.*5

# %% [markdown]
# ## 20 cm Case Non-Equilibrium

# %%
#--------------------------------
# Initalize the model
#--------------------------------
model = shallow_water_solver(kernel_language='Fortran')
model.set_solver(max_steps=1000000)
model.set_state_domain(x0, z0)
model.set_chezy_source_term(ks = ks, slope = bed_slope)
#model.set_mannings_source_term(mannings=0.022, slope=1/792.)

model.set_Dirichlet_BC(sOut20, q20cm)
model.set_inital_conditions(sOut20, 0.0)
model.set_controller(tfinal = 300, num_output_times=1)
model.run()

h = model.get_hf()
surf = h + z0

plt.plot(x0, surf)
plt.plot(x0, z0)

fig = plt.figure(figsize=(14, 6))
print(surf[len(x0)-1])
print(model.get_uf().mean())
# Out:
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:15:29,879 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:15:48,527 INFO CLAW: Solution 1 computed for time t=300.000000
# 0.23698340269770887
# 0.4262016673398106

# %%
run_name = 'dune_5_q_{0}_h_{1}_D50_{2}_v2'.format('20cm','237mm','0.8mm')

model = sdmodels.ShallowHydroMorphologicalModel()

#--------------------------------
# Set up the geometry
#--------------------------------
xc = x0.copy()
zc = z0.copy()
nx = len(xc)

model.setup_domain(x0, z0, dx)
model.setup_bed_properties( D50, repose_angle=repose_angle, rho_particle = rho_particle, nP = nP)
model.flow_boundary_conditions(q20cm, sOut20)
model.setup_chezy_hydro_model(ks, bed_slope)


#--------------------------------
# Set up the Morphodynamic Proerties
#--------------------------------
#morph_model = sdmodels.EulerWenoModel()
morph_model = sdmodels.TVD2ndWenoModel()
model.setup_morpho_model( morph_model, 
                           useAvalanche = True, 
                           useSmoother = False, 
                           sed_model='bagnold', 
                           useSlopeAdjust = False)


zc, u, q, h, qbedload = model.run(simTime, dt, extractionTime, None)
surf = zc + h

df = model.get_wave_dataframe()
df.to_csv('_output/{0}_waves.csv'.format(run_name))
np.save('_output/{0}_z.npy'.format(run_name),zc)
verts = model._verts
np.save('_output/{0}_verts.npy'.format(run_name, verts),verts)


fig = plt.figure(figsize=(14, 6))
plt.plot(xc,zc)
plt.plot(x0,z0)
plt.plot(xc, surf)

plt.xlabel('x (m)')
plt.ylabel('z (m)')
# Out:
#  Starting simulation....
# Number of time steps: 60.0 mins
# Grid dx = 0.009762202753441801
# Grid nx = 800
# Initializing hydrodynamic model...
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:15:48,789 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:07,965 INFO CLAW: Solution 1 computed for time t=300.000000
# Completed the intialization of the model
# D50:    0.0008
# Rho Particle:    2650.0
# Angle Repose Degrees:    30.0
# Max qbedload = 0.0004597642033302037
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:08,003 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:08,167 INFO CLAW: Solution 1 computed for time t=15.000000
# /pymorph/models/shallow_water_solver.py:64: RuntimeWarning: invalid value encountered in log
#   cf = ((1./kappa)*np.log(0.368*q[0,:]/ks) + Bs)
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:09,067 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:09,797 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:09,834 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:10,555 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:10,610 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:11,333 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:11,369 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:12,093 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:12,147 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:12,870 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:12,907 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:13,631 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:13,694 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:14,418 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:14,455 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:15,180 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:15,238 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:15,966 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:16,003 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:16,728 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:16,795 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:17,517 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:17,553 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:18,277 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:18,348 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:19,073 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:19,111 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:19,836 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:19,914 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:20,661 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:20,698 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:21,421 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:21,505 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:22,230 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:22,267 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:22,997 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:23,086 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:23,816 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:23,852 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:24,574 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:24,677 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:25,402 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:25,438 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:26,180 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:26,311 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:27,040 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:27,076 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:27,803 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:27,936 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:28,658 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:28,695 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:29,422 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:29,630 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:30,358 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:30,394 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:31,115 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:31,372 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:32,093 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:32,130 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:32,857 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:33,158 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:33,888 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:33,925 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:34,648 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:34,938 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:35,663 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:35,700 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:36,426 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:36,770 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:37,497 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:37,533 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:38,258 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:38,608 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:39,332 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:39,369 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:40,094 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:40,476 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:41,204 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:41,241 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:41,961 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:42,334 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:43,059 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:43,096 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:43,823 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:44,251 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:44,976 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16:45,013 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 16:16:45,733 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 16:16
INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:00,674 INFO CLAW: Solution 1 computed for time t=15.000000
# Time step: 250.0 mins - uavg: 0.4178753820802932 - Elevation 0.23214459163628157
# Courant number: 0.1380326259892741
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:00,745 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:01,979 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:02,051 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:03,280 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:03,347 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:04,588 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:04,659 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:05,895 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:05,961 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:07,194 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:07,393 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:08,630 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:08,697 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:09,930 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:10,003 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:11,237 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:11,304 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:12,545 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:12,617 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:13,852 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:13,920 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:15,159 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:15,341 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:16,576 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:16,642 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:17,873 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:17,945 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:19,177 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:19,244 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:20,476 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:20,549 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:21,787 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:21,854 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:23,090 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:23,294 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:24,533 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:24,599 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:25,834 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:25,906 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:27,144 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:27,211 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:28,439 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:28,511 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:29,746 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:29,813 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:31,046 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:31,242 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:32,475 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:32,541 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:33,773 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:33,847 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:35,088 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:35,155 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:36,386 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:36,458 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:37,694 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:37,760 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:38,990 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:39,192 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:40,420 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:40,487 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:41,723 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:41,796 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:43,031 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:43,097 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:44,325 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:44,401 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:45,636 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:45,703 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:46,934 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:47,154 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:48,384 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:48,450 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:49,683 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:49,754 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:50,987 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:51,054 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:52,287 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:52,360 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:53,599 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:53,665 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-05-17 17:54:54,903 INFO CLAW: Solution 1 computed for time t=15.000000
# qin  0.07894736842105263
# num_dim: 1
# 2019-05-17 17:54:55,093 INFO CLAW: Solution 0 computed for time t=0.000000

# %% [markdown]
# ## 32 cm Flow Case

# %%
#--------------------------------
# Initalize the model
#--------------------------------
model = shallow_water_solver(kernel_language='Fortran')
model.set_solver(max_steps=1000000)
model.set_state_domain(x0, z0)
model.set_chezy_source_term(ks = ks, slope = bed_slope)
#model.set_mannings_source_term(mannings=0.022, slope=1/792.)

model.set_Dirichlet_BC(sOut32, q32cm)
model.set_inital_conditions(sOut20, 0.0)
model.set_controller(tfinal = 300, num_output_times=1)
model.run()

h = model.get_hf()
surf = h + z0

plt.plot(x0, surf)
plt.plot(x0, z0)

fig = plt.figure(figsize=(14, 6))
print(surf[len(x0)-1])
print(model.get_uf().mean())

# %%
run_name = 'dune_5_q_{0}_h_{1}_D50_{2}_v2'.format('32m','357mm','0.8mm')

model = sdmodels.ShallowHydroMorphologicalModel()

#--------------------------------
# Set up the geometry
#--------------------------------
xc = x0.copy()
zc = z0.copy()
nx = len(xc)

model.setup_domain(x0, z0, dx)
model.setup_bed_properties( D50, repose_angle=repose_angle, rho_particle = rho_particle, nP = nP)
model.flow_boundary_conditions(q32cm, sOut32)
model.setup_chezy_hydro_model(ks, bed_slope)


#--------------------------------
# Set up the Morphodynamic Proerties
#--------------------------------
#morph_model = sdmodels.EulerWenoModel()
morph_model = sdmodels.TVD2ndWenoModel()
model.setup_morpho_model( morph_model, 
                           useAvalanche = True, 
                           useSmoother = False, 
                           sed_model='bagnold', 
                           useSlopeAdjust = False)


zc, u, q, h, qbedload = model.run(simTime, dt, extractionTime, None)
surf = zc + h

df = model.get_wave_dataframe()
df.to_csv('_output/{0}_waves.csv'.format(run_name))
np.save('_output/{0}_z.npy'.format(run_name),zc)
verts = model._verts
np.save('_output/{0}_verts.npy'.format(run_name, verts),verts)


fig = plt.figure(figsize=(14, 6))
plt.plot(xc,zc)
plt.plot(x0,z0)
plt.plot(xc, surf)

plt.xlabel('x (m)')
plt.ylabel('z (m)')

# %%
df
