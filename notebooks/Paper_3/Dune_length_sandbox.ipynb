# %%
from scipy import signal
import math
import collections
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import librosa

# %matplotlib inline

# %%
x = np.linspace(0, 1, 500)
z = signal.sawtooth(2 * np.pi * 5 * x)
plt.plot(x, z)

# %%
x2 = np.linspace(0, 0.75, 500)
z2 = signal.sawtooth(2 * np.pi * 5 * x)

# %%
plt.plot(x, z)
plt.plot(x2, z2)
