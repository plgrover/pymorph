# %%
# %matplotlib widget
import os,sys
import csv
import copy
import math
import collections
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from clawpack import pyclaw
from clawpack import riemann
import numpy as np
from scipy.integrate import simps, trapz
from scipy.interpolate import interp1d

sys.path.append("/pymorph")
from schemes.weno import get_left_flux,get_right_flux
from schemes.weno import get_stencil
import sediment_transport.sed_trans as sedtrans
import morph_geom_lib as mgl

from models.shallow_water_solver import shallow_water_solver
from schemes.avalanche_scheme import *

from matplotlib.collections import LineCollection
from mpl_toolkits.mplot3d import Axes3D

from IPython.display import display, Math, Latex


# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
plt.style.use(['dark_background'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
profile_folder = '/pymorph/notebooks/Paper_3/flume_profile_smoothed_v002.txt'
xc, z0 = mgl.readQueensFlume(profile_folder,1)
plt.plot(xc,z0)
zc = z0.copy()
# Out:
# Z: 87

# %%
#--------------------------------
# Set up the constants
#--------------------------------
nP=0.4
Slope = 1.26/1000 # Based on table 4.1 in Wiebe
mannings = 0.0248
beta = 0.01

D50 = 0.001

nx = len(xc)
# 32 cm Case 
Qc132 = 0.045
Qc120 = 0.020
B = 0.76
Qtotal32 = Qc132 * 3.
Qtotal20 = Qc120 * 3.
q32cm = Qtotal32 / B
q20cm = Qtotal20 / B

#sws.set_boundary_conditions()
hout = 0.357
Qin = q32cm

sws = shallow_water_solver(kernel_language='Fortran')
sws.set_solver(max_steps=100000)
sws.set_state_domain(xc,zc)
sws.set_mannings_source_term(mannings=mannings, slope=Slope)
sws.set_Dirichlet_BC(hout,Qin)
sws.set_inital_conditions(hout, 0.0)
sws.set_controller(tfinal=300., num_output_times=3)
sws.run()
cntrl = sws.get_controller()

h = sws.get_hf()
u = sws.get_uf()
q = sws.get_qf()


plt.plot(xc, h+zc)
plt.plot(xc,zc)

u = sws.get_uf()
h = sws.get_hf()
tau32 = np.zeros(nx)
for i in range(0,nx): #i=2
    tau32[i] = sedtrans.get_bed_shear(h[i],u[i],D50)
    
plt.plot(xc,tau32,'c-')

plt.plot(xc,zc,'r')
# Out:
# 2019-04-26 18:35:17,910 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:35:19,406 INFO CLAW: Solution 1 computed for time t=100.000000
# 2019-04-26 18:35:21,041 INFO CLAW: Solution 2 computed for time t=200.000000
# 2019-04-26 18:35:22,537 INFO CLAW: Solution 3 computed for time t=300.000000

# %%
#--------------------------------
# Set up the constants
#--------------------------------
nP=0.4
Slope = 1.26/1000 # Based on table 4.1 in Wiebe
mannings = 0.0248
beta = 0.01

# 32 cm Case 
Qc132 = 0.045
Qc120 = 0.020
B = 0.76
Qtotal32 = Qc132 * 3.
Qtotal20 = Qc120 * 3.
q32cm = Qtotal32 / B
q20cm = Qtotal20 / B

#sws.set_boundary_conditions()
hout = 0.237
Qin = q20cm

sws = shallow_water_solver(kernel_language='Fortran')
sws.set_solver(max_steps=100000)
sws.set_state_domain(xc,zc)
sws.set_mannings_source_term(mannings=mannings, slope=Slope)
sws.set_Dirichlet_BC(hout,Qin)
sws.set_inital_conditions(hout, 0.0)
sws.set_controller(tfinal=300., num_output_times=3)
sws.run()
cntrl = sws.get_controller()

h = sws.get_hf()
u = sws.get_uf()
q = sws.get_qf()


plt.plot(xc, h+zc)
plt.plot(xc,zc)

u = sws.get_uf()
h = sws.get_hf()
tau20 = np.zeros(nx)
for i in range(0,nx): #i=2
    tau20[i] = sedtrans.get_bed_shear(h[i],u[i],D50)
    
plt.plot(xc,tau32/tau32.max(),'c-')
plt.plot(xc, tau20/tau20.max(), 'g')

plt.plot(xc,zc,'r')
# Out:
# 2019-04-26 18:36:53,438 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:36:54,622 INFO CLAW: Solution 1 computed for time t=100.000000
# 2019-04-26 18:36:55,784 INFO CLAW: Solution 2 computed for time t=200.000000
# 2019-04-26 18:36:56,928 INFO CLAW: Solution 3 computed for time t=300.000000

# %%
plt.figure(figsize=(12, 4))
plt.plot(xc,tau32,'c-')
plt.plot(xc, tau20, 'g')

plt.plot(xc,zc,'r')

# %%
#--------------------------------
# Initialize the sed transport 
#--------------------------------    
# Eq 57
nx = len(xc)
qbedload = np.zeros(nx)
roe_speed = np.zeros(nx)
flux = np.zeros(nx)

# Sediment properties
D50 = 0.001     # Particle Diameter
rho_particule = 2650



#--------------------------------
#  Setup the model run parameters
#--------------------------------
simTime = 60*60 # Runtime in seconds
dt = 2 # Time step size (s)
nt = int(simTime/dt)  # Number of time steps

dx = sws.get_state().grid.delta[0]
#--------------------------------
# Set up the model reporting parameters

z0 = zc.copy() 
z600 = zc.copy() 
z2000 = zc.copy()
verts = []
extractionInterval = 60.*2
tsteps=[]
iterations = 0
cntr=0

#sws.set_boundary_conditions()
hout = 0.357
Qin = q32cm

sws = shallow_water_solver(kernel_language='Fortran')
sws.set_solver(max_steps=100000)
sws.set_state_domain(xc,zc)
sws.set_mannings_source_term(mannings=mannings, slope=Slope)
sws.set_boundary_conditions()
sws.set_inital_conditions(hout, 0.0)
sws.set_controller(tfinal=300., num_output_times=3)
sws.run()
cntrl = sws.get_controller()

h = sws.get_hf()
u = sws.get_uf()
q = sws.get_qf()
#--------------------------------
#  Run the model
#--------------------------------
for n in range(1,nt):  
    zn = zc.copy() 
    for i in range(0,nx): #i=2
        zloc = get_stencil(zn,i-2,i+4)        
        # Since k=3
        # stencil is i-2 to i+2 
        qloc = get_stencil(qbedload,i-2,i+4)
        if len(qloc)!=6:
            raise ValueError('Stencil is incorrect')
 
        # Determine the Upwind flux
        # The 0.5 comes from the c+abs(c) which is 2 if the wave speed is +ive
        # this is the evaluation of the left and right based fluxes. Eq. 18 and 19        
        if (zloc[3]-zloc[2]) == 0.0:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2]) )
        else:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2])/ (zloc[3]-zloc[2]) )
        
        if roe_speed[i] >= 0.0:
            flux[i] = get_left_flux(qloc)
        else:
            flux[i] = get_right_flux(qloc)
        
    # Need the sign of the phase speed
    # Need to check this out
    for i in range(0,nx): #i=2       
        floc = get_stencil(flux,i-1,i+1)
        zc[i] = zn[i]-(1./(1.-nP))*dt/dx*(floc[1]-floc[0])
    
    bed_max_delta = np.max(np.abs(zn - zc))
    
    # Apply the avalanche model
    zc, iterations1 = avalanche_model(dx,xc, zc, adjustment_angle=28.)
    # Now flip it to run in reverse
    zflip = np.flip(zc, axis=0)
    zflip, iterations1 = avalanche_model(dx,xc, zflip, adjustment_angle=28.)
    zc = np.flip(zflip, axis=0)
    
    #zc = z_updated.copy()
    
    # Re-run the solver and updated the sediment transport
    # Check if the avalanche model was updated OR the bed changed greater than the threshold
    #if iterations > 10 or bed_max_delta > 0.00005:
    iterations+=1
    if iterations > 2:        
        sws = shallow_water_solver(kernel_language='Fortran')
        sws.set_solver(max_steps=100000)
        sws.set_state_domain(xc,zc)
        sws.set_mannings_source_term(mannings=mannings, slope=1.26/1000.)
        sws.set_conditions_from_previous(h, q)
        sws.set_boundary_conditions()
        sws.set_controller(tfinal=20., num_output_times=1)
        sws.run()
        cntrl = sws.get_controller()      

        h = sws.get_hf()
        u = sws.get_uf()
        q = sws.get_qf()
        surf = h + zc
        
        iterations = 0
        
    slope = np.gradient(zc,dx)
    
    if 1==2:
        # ----------------------------------
        # Apply the two-step smooting scheme Eq. 6 in Niemann et al 2011.
        # ----------------------------------
        zhat = np.zeros(nx)
        for i in range(0, nx):  # i=2
            zlocal = get_stencil(zc, i - 1, i + 2)
            zhat[i] = 0.5*zlocal[1] + 0.25*(zlocal[0]+zlocal[2])

        for i in range(0, nx):
            zhatlocal = get_stencil(zhat, i - 1, i + 2)
            zc[i] = (3./2.)*zhatlocal[1] - 0.25*(zhatlocal[0]+zhatlocal[2])


    ## Nov 13 2018 - Can modify later
    for i in range(0,nx): #i=2        
        #zlocal = get_stencil(zc,i-2,i+2)
        #qbedload[i] = sedtrans.get_unit_bed_load2(h[i],u[i],D50,rho_particule,type='bagnold')
        qbedload[i] = sedtrans.get_unit_bed_load_slope(h[i],u[i],D50,slope[i], 
                                                       rho_particule, 
                                                       angleReposeDegrees = 30.0, 
                                                       type='bagnold',
                                                        useSlopeAdjust=False)

    
    if (n*dt / extractionInterval) == math.floor(n*dt / extractionInterval):
        verts.append(list(zip(xc.copy(),zc.copy())))
        tsteps.append(n*dt)        
        np.save('flume_dunes', verts)
    
    cntr += 1
    if cntr == extractionInterval:
        cntr = 0
        print('Time step {0} of {1} - bed_max_delta {2}'.format(n,nt,bed_max_delta))    
        
print('Done')
# Out:
# 2019-04-26 18:38:33,943 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:35,394 INFO CLAW: Solution 1 computed for time t=100.000000
# 2019-04-26 18:38:36,992 INFO CLAW: Solution 2 computed for time t=200.000000
# 2019-04-26 18:38:38,531 INFO CLAW: Solution 3 computed for time t=300.000000
# 2019-04-26 18:38:38,552 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:38,850 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:38,871 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:39,240 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:39,260 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:39,613 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:39,633 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:39,960 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:39,985 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:40,304 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:40,331 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:40,636 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:40,652 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:41,021 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:41,041 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:41,362 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:41,383 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:41,692 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:41,715 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:42,055 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:42,080 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:42,403 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:42,420 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:42,736 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:42,757 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:43,109 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:43,130 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38:43,453 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:38:43,471 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:38
INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:41:59,846 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:41:59,868 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:00,389 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:00,435 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:00,985 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:01,008 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:01,362 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:01,381 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:01,761 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:01,791 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:02,115 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:02,143 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:02,459 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:02,506 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:02,873 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:02,907 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:03,259 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:03,287 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:03,631 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:03,654 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:04,026 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:04,065 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:04,411 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:04,428 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:04,793 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:04,836 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:05,204 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:05,236 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:05,568 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:05,599 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:05,936 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:05,959 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:06,331 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:06,356 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:06,687 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:06,716 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:07,057 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:07,080 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:07,417 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:07,448 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:07,775 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:07,796 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:08,125 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:08,141 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:08,492 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:08,521 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:08,934 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:08,966 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:09,328 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:09,348 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:09,715 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:09,735 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:10,098 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:10,130 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:10,520 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:10,537 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:10,898 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:10,921 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:11,248 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:11,266 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:11,604 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:11,628 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:12,049 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:12,077 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:12,554 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:12,588 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:13,087 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:13,128 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:13,602 INFO CLAW: Solution 1 computed for time t=20.000000
# Time step 1680 of 1800 - bed_max_delta 0.00033409706090477276
# 2019-04-26 18:42:13,633 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:14,002 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:14,019 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:14,327 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:14,353 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:14,727 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:14,751 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:15,109 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:15,136 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:15,447 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:15,471 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:15,838 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:15,861 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:16,203 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:16,226 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:16,570 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:16,592 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:16,971 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:17,002 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:17,327 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:17,352 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:17,658 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:17,683 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:18,072 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:18,095 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:18,428 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:18,458 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:18,783 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:18,800 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:19,167 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:19,185 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:19,570 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:19,591 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:19,970 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:19,991 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:20,403 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:20,434 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:20,798 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:20,823 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:21,218 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:21,249 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:21,598 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:21,623 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:21,948 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:21,977 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:22,352 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:22,372 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:22,688 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:22,706 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:23,050 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:23,072 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:23,526 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:23,587 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:23,931 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:23,947 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:24,269 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:24,291 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:24,640 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:24,663 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:25,023 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:25,048 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:25,421 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:25,446 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:25,769 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:25,794 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:26,162 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:26,185 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:26,550 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:26,571 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:26,952 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:26,983 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:27,335 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:27,376 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:27,707 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:27,729 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:28,037 INFO CLAW: Solution 1 computed for time t=20.000000
# 2019-04-26 18:42:28,055 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-26 18:42:28,390 INFO CLAW: Solution 1 computed for time t=20.000000
# Done

# %%
fig = plt.figure(figsize=(14, 6))
plt.plot(xc,surf)
plt.plot(xc,zc,'r')
plt.plot(xc,z0)

# %%
from matplotlib.collections import LineCollection
from mpl_toolkits.mplot3d import Axes3D




lines = LineCollection(verts)
fig = plt.figure(figsize=(18, 16))
ax = fig.gca(projection='3d')
lines.set_alpha(0.7)
ax.add_collection3d(lines, zs=tsteps, zdir='y')
ax.set_xlim3d(0, 2.6)
ax.set_zlim3d(-0.1, .2)
ax.set_ylim3d(0, 18000)
ax.set_zlabel('$z_b$')
ax.set_ylabel('$t(sec)$')
ax.set_xlabel('$x(m)$')
# Out:
# Text(0.5, 0, '$x(m)$')

# %%
u = sws.get_uf()
h = sws.get_hf()
tau32 = np.zeros(nx)
for i in range(0,nx): #i=2
    tau32[i] = sedtrans.get_bed_shear(h[i],u[i],D50)
    
plt.plot(xc,tau32,'c-')

plt.plot(xc,zc,'r')
