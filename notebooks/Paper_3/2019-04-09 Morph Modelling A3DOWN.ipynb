# %%
# %matplotlib widget
import os,sys
import csv
import copy
import math
import collections
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from clawpack import pyclaw
from clawpack import riemann
import numpy as np
from scipy.integrate import simps, trapz
from scipy.interpolate import interp1d

sys.path.append("/pymorph")
from schemes.weno import get_left_flux,get_right_flux
from schemes.weno import get_stencil
import sediment_transport.sed_trans as sedtrans

from models.shallow_water_solver import shallow_water_solver
from schemes.avalanche_scheme import *

from matplotlib.collections import LineCollection
from mpl_toolkits.mplot3d import Axes3D

from IPython.display import display, Math, Latex


# %load_ext autoreload
# %autoreload 2

plt.style.use(['dark_background'])

# %%
profile_folder = '/data/PhD/A3DOWN 2006-06-09 (S-800, 30-15cm)'

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
    


def readWiebeFile(filepath, resolution = 0.5):
    xs = []
    zs = []
    with open(filepath) as f:
        for line in f:
            values = line.split(',')
            if is_number(values[0]) and is_number(values[1]):
                x = float(values[0])/100.
                z = float(values[1])/100.
                xs.append(x)
                zs.append(z)
                
    xs = np.array(xs)
    zs = np.array(zs)
    
    #--------------------------------
    # Increase the resolution on the grid
    #--------------------------------
    xmax = 12.0 #xs.max()
    nx = len(xs)
    f = interp1d(xs, zs)
    
    xnew = np.linspace(0., xmax, num=800)
    znew = f(xnew)
    return xnew, znew


xprofile = None
zdict = {}

for filename in os.listdir(profile_folder):
    name = filename.split('.')[0]
    profile = None
    if len(name)==10:
        profile = '0{0}'.format(name[-1:])
    else:
        profile = name[-2:]
    
    x, z = readWiebeFile(os.path.join(profile_folder,filename), resolution=0.25)
    
    xprofile = x
    zdict[profile] = z

profileDf = pd.DataFrame(zdict)

profileDf = profileDf.reindex(sorted(profileDf.columns), axis=1)

# %%
plt.plot(xprofile,profileDf['00'])
plt.show()
# Out:
# FigureCanvasNbAgg()

# %%
xprofile[1]-xprofile[0]
# Out:
# 0.015018773466833541

# %%
#--------------------------------
# Set up the constants
#--------------------------------
nP=0.4
Slope = 1.26/1000 # Based on table 4.1 in Wiebe
mannings = 0.022
water_surface= 0.20      # Surface water elevation
beta = 0.01

starting_profile = '02'

# Sediment properties
D50 = 0.001     # Particle Diameter
rho_particule = 2650


nx = len(xprofile)
xmax = xprofile.max()
#--------------------------------
# Set up the domain, BCs and ICs
#--------------------------------
import logging
logger = logging.getLogger('pyclaw')
logger.setLevel(logging.CRITICAL)

x = pyclaw.Dimension(0.0,xmax,len(xprofile),name='x')
domain = pyclaw.Domain(x)
state = pyclaw.State(domain,1)
xc = state.grid.x.centers
dx = state.grid.delta[0]
print('Grid dx = {0}'.format(dx))
print('Grid nx = {0}'.format(len(xc)))

zc = np.array(profileDf[starting_profile].tolist().copy())
z_hydro = np.array(profileDf[starting_profile].tolist().copy())

 # Gravitational constant
state.problem_data['grav'] = 9.81
state.problem_data['sea_level'] = 0.0


# Set up the inital state of the flow
shw_slvr = shallow_solver(domain, slope=Slope, mannings=mannings)
u, surf,h = shw_slvr.run(zc,water_surface,3000)


if np.isnan(u).any():
    # Get the flow
    print( u)
    raise ValueError('Failed to calculate the flow')
# Out:
# Grid dx = 0.015
# Grid nx = 800
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-865bc76c503a> in <module>
#      41
#      42 # Set up the inital state of the flow
# ---> 43 shw_slvr = shallow_solver(domain, slope=Slope, mannings=mannings)
#      44 u, surf,h = shw_slvr.run(zc,water_surface,3000)
#      45
#
# NameError: name 'shallow_solver' is not defined

# %%
fig = plt.figure(figsize=(12, 4))
plt.plot(xc,surf)
plt.plot(xc,zc,'r')
# Out:
# FigureCanvasNbAgg()

# %%
#--------------------------------
# Initialize the sed transport 
#--------------------------------    
# Eq 57

qbedload = np.zeros(nx)
roe_speed = np.zeros(nx)
flux = np.zeros(nx)

#--------------------------------
#  Setup the model run parameters
#--------------------------------
simTime = 1800. # Runtime in seconds
dt = 1 # Time step size (s)
nt = int(simTime/dt)  # Number of time steps


#--------------------------------
# Set up the model reporting parameters
#--------------------------------
z0 = zc.copy() 
z600 = zc.copy() 
z2000 = zc.copy()
verts = []
extractionInterval = 120.
tsteps=[]
iterations = 0
cntr=0
#--------------------------------
#  Run the model
#--------------------------------
for n in range(1,nt):  
    zn = zc.copy() 
    for i in range(0,nx): #i=2
        zloc = get_stencil(zn,i-2,i+4)        
        # Since k=3
        # stencil is i-2 to i+2 
        qloc = get_stencil(qbedload,i-2,i+4)
        if len(qloc)!=6:
            raise ValueError('Stencil is incorrect')
 
        # Determine the Upwind flux
        # The 0.5 comes from the c+abs(c) which is 2 if the wave speed is +ive
        # this is the evaluation of the left and right based fluxes. Eq. 18 and 19        
        if (zloc[3]-zloc[2]) == 0.0:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2]) )
        else:
            roe_speed[i]=np.sign( (qloc[3]-qloc[2])/ (zloc[3]-zloc[2]) )
        
        if roe_speed[i] >= 0.0:
            flux[i] = get_left_flux(qloc)
        else:
            flux[i] = get_right_flux(qloc)
        
    # Need the sign of the phase speed
    # Need to check this out
    for i in range(0,nx): #i=2       
        floc = get_stencil(flux,i-1,i+1)
        zc[i] = zn[i]-(1./(1.-nP))*dt/dx*(floc[1]-floc[0])
    
    bed_max_delta = np.max(np.abs(zn - zc))
    
    # Apply the avalanche model
    zc, iterations1 = avalanche_model(dx,xc, zc, adjustment_angle=28.)
    # Now flip it to run in reverse
    zflip = np.flip(zc, axis=0)
    zflip, iterations1 = avalanche_model(dx,xc, zflip, adjustment_angle=28.)
    zc = np.flip(zflip, axis=0)
    
    #zc = z_updated.copy()
    
    # Re-run the solver and updated the sediment transport
    # Check if the avalanche model was updated OR the bed changed greater than the threshold
    #if iterations > 10 or bed_max_delta > 0.00005:
    iterations+=1
    if iterations > 2:
        u, surf,h = shw_slvr.run(zc,water_surface, 120)
        iterations = 0

    slope = np.gradient(zc,dx)
    
    ## Nov 13 2018 - Can modify later
    for i in range(0,nx): #i=2        
        #zlocal = get_stencil(zc,i-2,i+2)
        #qbedload[i] = sedtrans.get_unit_bed_load2(h[i],u[i],D50,rho_particule,type='bagnold')
        qbedload[i] = sedtrans.get_unit_bed_load_slope(h[i],u[i],D50,slope[i], 
                                                       rho_particule, 
                                                       angleReposeDegrees = 30.0, 
                                                       type='bagnold',
                                                        useSlopeAdjust=False)

    
    if (n*dt / extractionInterval) == math.floor(n*dt / extractionInterval):
        verts.append(list(zip(xc.copy(),zc.copy())))
        tsteps.append(n*dt)        
        np.save('flume_dunes', verts)
    
    cntr += 1
    if cntr == extractionInterval:
        cntr = 0
        print('Time step {0} of {1} - bed_max_delta {2}'.format(n,nt,bed_max_delta))    
        
print('Done')
# Out:
# 2019-04-09 23:01:32,127 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:01:45,010 INFO CLAW: Solution 1 computed for time t=70.921507
# 2019-04-09 23:01:45,281 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:01:57,099 INFO CLAW: Solution 1 computed for time t=70.921468
# 2019-04-09 23:01:57,295 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:02:09,141 INFO CLAW: Solution 1 computed for time t=70.921471
# 2019-04-09 23:02:09,435 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:02:21,561 INFO CLAW: Solution 1 computed for time t=70.921373
# 2019-04-09 23:02:21,816 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:02:33,329 INFO CLAW: Solution 1 computed for time t=70.921371
# 2019-04-09 23:02:33,601 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:02:45,256 INFO CLAW: Solution 1 computed for time t=70.921392
# 2019-04-09 23:02:45,513 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:02:57,771 INFO CLAW: Solution 1 computed for time t=70.921395
# 2019-04-09 23:02:58,026 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:03:09,589 INFO CLAW: Solution 1 computed for time t=70.921493
# 2019-04-09 23:03:09,869 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:03:22,549 INFO CLAW: Solution 1 computed for time t=70.921485
# 2019-04-09 23:03:22,840 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:03:36,018 INFO CLAW: Solution 1 computed for time t=70.921277
# 2019-04-09 23:03:36,634 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:03:49,089 INFO CLAW: Solution 1 computed for time t=70.920751
# 2019-04-09 23:03:49,547 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:04:01,666 INFO CLAW: Solution 1 computed for time t=70.920077
# 2019-04-09 23:04:02,153 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:04:13,638 INFO CLAW: Solution 1 computed for time t=70.919442
# 2019-04-09 23:04:14,079 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:04:25,916 INFO CLAW: Solution 1 computed for time t=70.918853
# 2019-04-09 23:04:26,598 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:04:38,473 INFO CLAW: Solution 1 computed for time t=70.918281
# 2019-04-09 23:04:38,904 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:04:50,625 INFO CLAW: Solution 1 computed for time t=70.917795
# 2019-04-09 23:04:51,076 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:05:03,298 INFO CLAW: Solution 1 computed for time t=70.917438
# 2019-04-09 23:05:03,907 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:05:15,663 INFO CLAW: Solution 1 computed for time t=70.917100
# 2019-04-09 23:05:16,133 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:05:27,984 INFO CLAW: Solution 1 computed for time t=70.916681
# 2019-04-09 23:05:28,477 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:05:40,856 INFO CLAW: Solution 1 computed for time t=70.916296
# 2019-04-09 23:05:41,416 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:05:52,955 INFO CLAW: Solution 1 computed for time t=70.915831
# 2019-04-09 23:05:53,565 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:06:05,686 INFO CLAW: Solution 1 computed for time t=70.915240
# 2019-04-09 23:06:06,448 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:06:18,052 INFO CLAW: Solution 1 computed for time t=70.914634
# 2019-04-09 23:06:18,581 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:06:31,162 INFO CLAW: Solution 1 computed for time t=70.913912
# 2019-04-09 23:06:31,857 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:06:42,572 INFO CLAW: Solution 1 computed for time t=70.912904
# 2019-04-09 23:06:43,015 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:06:53,456 INFO CLAW: Solution 1 computed for time t=70.911700
# 2019-04-09 23:06:54,007 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:07:05,732 INFO CLAW: Solution 1 computed for time t=70.910775
# 2019-04-09 23:07:06,215 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:07:17,887 INFO CLAW: Solution 1 computed for time t=70.910117
# 2019-04-09 23:07:18,356 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:07:29,415 INFO CLAW: Solution 1 computed for time t=70.909625
# 2019-04-09 23:07:29,920 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:07:41,378 INFO CLAW: Solution 1 computed for time t=70.909178
# 2019-04-09 23:07:41,919 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:07:53,243 INFO CLAW: Solution 1 computed for time t=70.908667
# 2019-04-09 23:07:53,661 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:08:04,603 INFO CLAW: Solution 1 computed for time t=70.908285
# 2019-04-09 23:08:05,036 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:08:18,128 INFO CLAW: Solution 1 computed for time t=70.907864
# 2019-04-09 23:08:18,626 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:08:29,769 INFO CLAW: Solution 1 computed for time t=70.907332
# 2019-04-09 23:08:30,354 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:08:43,462 INFO CLAW: Solution 1 computed for time t=70.906736
# 2019-04-09 23:08:43,910 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:08:56,845 INFO CLAW: Solution 1 computed for time t=70.906168
# 2019-04-09 23:08:57,255 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:09:08,331 INFO CLAW: Solution 1 computed for time t=70.905633
# 2019-04-09 23:09:08,829 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:09:19,735 INFO CLAW: Solution 1 computed for time t=70.905060
# 2019-04-09 23:09:20,196 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:09:31,187 INFO CLAW: Solution 1 computed for time t=70.904418
# 2019-04-09 23:09:31,703 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:09:43,309 INFO CLAW: Solution 1 computed for time t=70.903690
# Time step 120 of 1800 - bed_max_delta 0.000716340202606254
# 2019-04-09 23:09:43,796 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:09:56,091 INFO CLAW: Solution 1 computed for time t=70.903058
# 2019-04-09 23:09:56,451 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:10:07,943 INFO CLAW: Solution 1 computed for time t=70.902853
# 2019-04-09 23:10:08,535 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:10:19,685 INFO CLAW: Solution 1 computed for time t=70.902144
# 2019-04-09 23:10:20,119 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:10:32,052 INFO CLAW: Solution 1 computed for time t=70.901907
# 2019-04-09 23:10:32,470 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:10:43,615 INFO CLAW: Solution 1 computed for time t=70.901672
# 2019-04-09 23:10:44,033 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:10:55,257 INFO CLAW: Solution 1 computed for time t=70.901338
# 2019-04-09 23:10:55,715 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:11:07,270 INFO CLAW: Solution 1 computed for time t=70.900890
# 2019-04-09 23:11:07,741 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:11:19,077 INFO CLAW: Solution 1 computed for time t=70.900337
# 2019-04-09 23:11:19,511 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:11:31,551 INFO CLAW: Solution 1 computed for time t=70.899783
# 2019-04-09 23:11:32,058 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:11:43,560 INFO CLAW: Solution 1 computed for time t=70.899134
# 2019-04-09 23:11:44,188 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:11:55,429 INFO CLAW: Solution 1 computed for time t=70.898476
# 2019-04-09 23:11:55,975 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:12:08,039 INFO CLAW: Solution 1 computed for time t=70.898001
# 2019-04-09 23:12:08,481 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:12:19,782 INFO CLAW: Solution 1 computed for time t=70.897669
# 2019-04-09 23:12:20,237 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:12:31,552 INFO CLAW: Solution 1 computed for time t=70.897312
# 2019-04-09 23:12:32,113 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:12:44,088 INFO CLAW: Solution 1 computed for time t=70.896831
# 2019-04-09 23:12:44,628 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:12:55,560 INFO CLAW: Solution 1 computed for time t=70.896226
# 2019-04-09 23:12:56,054 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:13:07,224 INFO CLAW: Solution 1 computed for time t=70.895516
# 2019-04-09 23:13:07,729 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:13:19,366 INFO CLAW: Solution 1 computed for time t=70.894784
# 2019-04-09 23:13:19,918 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:13:30,991 INFO CLAW: Solution 1 computed for time t=70.894022
# 2019-04-09 23:13:31,490 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:13:43,506 INFO CLAW: Solution 1 computed for time t=70.893570
# 2019-04-09 23:13:44,000 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:13:55,344 INFO CLAW: Solution 1 computed for time t=70.893234
# 2019-04-09 23:13:55,817 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:14:07,039 INFO CLAW: Solution 1 computed for time t=70.892992
# 2019-04-09 23:14:07,604 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:14:20,626 INFO CLAW: Solution 1 computed for time t=70.892501
# 2019-04-09 23:14:21,173 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:14:32,819 INFO CLAW: Solution 1 computed for time t=70.891863
# 2019-04-09 23:14:33,318 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:14:44,522 INFO CLAW: Solution 1 computed for time t=70.891007
# 2019-04-09 23:14:45,000 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:14:56,232 INFO CLAW: Solution 1 computed for time t=70.890050
# 2019-04-09 23:14:56,722 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:15:07,712 INFO CLAW: Solution 1 computed for time t=70.889209
# 2019-04-09 23:15:08,173 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:15:19,012 INFO CLAW: Solution 1 computed for time t=70.888778
# 2019-04-09 23:15:19,559 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:15:30,566 INFO CLAW: Solution 1 computed for time t=70.888552
# 2019-04-09 23:15:31,015 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:15:41,992 INFO CLAW: Solution 1 computed for time t=70.888202
# 2019-04-09 23:15:42,416 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:15:53,842 INFO CLAW: Solution 1 computed for time t=70.887943
# 2019-04-09 23:15:54,236 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:16:05,085 INFO CLAW: Solution 1 computed for time t=70.887908
# 2019-04-09 23:16:05,472 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:16:16,361 INFO CLAW: Solution 1 computed for time t=70.887825
# 2019-04-09 23:16:16,807 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:16:28,892 INFO CLAW: Solution 1 computed for time t=70.887230
# 2019-04-09 23:16:29,283 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:16:40,588 INFO CLAW: Solution 1 computed for time t=70.886768
# 2019-04-09 23:16:41,004 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:16:51,984 INFO CLAW: Solution 1 computed for time t=70.886499
# 2019-04-09 23:16:52,432 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:17:03,693 INFO CLAW: Solution 1 computed for time t=70.885934
# 2019-04-09 23:17:04,103 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:17:14,898 INFO CLAW: Solution 1 computed for time t=70.885180
# 2019-04-09 23:17:15,353 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:17:26,168 INFO CLAW: Solution 1 computed for time t=70.884843
# 2019-04-09 23:17:26,576 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:17:38,073 INFO CLAW: Solution 1 computed for time t=70.884742
# Time step 240 of 1800 - bed_max_delta 0.0006939705256183287
# 2019-04-09 23:17:38,422 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:17:49,199 INFO CLAW: Solution 1 computed for time t=70.883751
# 2019-04-09 23:17:49,689 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:18:00,483 INFO CLAW: Solution 1 computed for time t=70.883010
# 2019-04-09 23:18:00,877 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:18:12,090 INFO CLAW: Solution 1 computed for time t=70.883253
# 2019-04-09 23:18:12,465 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:18:23,388 INFO CLAW: Solution 1 computed for time t=70.882889
# 2019-04-09 23:18:23,771 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:18:35,517 INFO CLAW: Solution 1 computed for time t=70.882729
# 2019-04-09 23:18:36,390 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:18:47,480 INFO CLAW: Solution 1 computed for time t=70.881982
# 2019-04-09 23:18:48,014 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:18:58,958 INFO CLAW: Solution 1 computed for time t=70.881683
# 2019-04-09 23:18:59,495 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:19:10,789 INFO CLAW: Solution 1 computed for time t=70.881167
# 2019-04-09 23:19:11,299 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:19:22,175 INFO CLAW: Solution 1 computed for time t=70.879980
# 2019-04-09 23:19:22,742 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:19:34,252 INFO CLAW: Solution 1 computed for time t=70.878852
# 2019-04-09 23:19:34,905 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:19:46,209 INFO CLAW: Solution 1 computed for time t=70.878032
# 2019-04-09 23:19:46,722 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:19:59,138 INFO CLAW: Solution 1 computed for time t=70.877537
# 2019-04-09 23:19:59,687 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:20:10,475 INFO CLAW: Solution 1 computed for time t=70.877147
# 2019-04-09 23:20:10,929 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:20:22,038 INFO CLAW: Solution 1 computed for time t=70.876885
# 2019-04-09 23:20:22,576 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:20:34,155 INFO CLAW: Solution 1 computed for time t=70.876564
# 2019-04-09 23:20:34,785 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:20:46,851 INFO CLAW: Solution 1 computed for time t=70.875893
# 2019-04-09 23:20:47,459 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:20:58,630 INFO CLAW: Solution 1 computed for time t=70.875024
# 2019-04-09 23:20:59,401 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:21:10,864 INFO CLAW: Solution 1 computed for time t=70.874213
# 2019-04-09 23:21:11,390 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:21:23,186 INFO CLAW: Solution 1 computed for time t=70.873574
# 2019-04-09 23:21:23,602 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:21:34,611 INFO CLAW: Solution 1 computed for time t=70.873158
# 2019-04-09 23:21:35,275 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:21:47,005 INFO CLAW: Solution 1 computed for time t=70.872916
# 2019-04-09 23:21:47,480 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:22:03,254 INFO CLAW: Solution 1 computed for time t=70.872776
# 2019-04-09 23:22:03,676 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:22:16,393 INFO CLAW: Solution 1 computed for time t=70.872699
# 2019-04-09 23:22:17,673 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:22:30,278 INFO CLAW: Solution 1 computed for time t=70.872566
# 2019-04-09 23:22:30,701 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:22:41,541 INFO CLAW: Solution 1 computed for time t=70.872149
# 2019-04-09 23:22:41,922 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:22:51,973 INFO CLAW: Solution 1 computed for time t=70.871501
# 2019-04-09 23:22:52,352 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:23:04,688 INFO CLAW: Solution 1 computed for time t=70.870856
# 2019-04-09 23:23:05,103 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:23:15,928 INFO CLAW: Solution 1 computed for time t=70.870365
# 2019-04-09 23:23:16,329 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:23:27,164 INFO CLAW: Solution 1 computed for time t=70.869966
# 2019-04-09 23:23:27,605 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:23:39,011 INFO CLAW: Solution 1 computed for time t=70.869572
# 2019-04-09 23:23:39,305 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:23:50,101 INFO CLAW: Solution 1 computed for time t=70.869382
# 2019-04-09 23:23:50,590 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:24:01,567 INFO CLAW: Solution 1 computed for time t=70.868843
# 2019-04-09 23:24:02,074 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:24:13,474 INFO CLAW: Solution 1 computed for time t=70.868605
# 2019-04-09 23:24:13,856 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:24:24,692 INFO CLAW: Solution 1 computed for time t=70.868441
# 2019-04-09 23:24:25,057 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:24:36,623 INFO CLAW: Solution 1 computed for time t=70.868201
# 2019-04-09 23:24:37,021 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:24:47,954 INFO CLAW: Solution 1 computed for time t=70.867829
# 2019-04-09 23:24:48,367 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:24:59,199 INFO CLAW: Solution 1 computed for time t=70.867421
# 2019-04-09 23:24:59,583 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:25:11,104 INFO CLAW: Solution 1 computed for time t=70.867056
# 2019-04-09 23:25:11,485 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:25:22,266 INFO CLAW: Solution 1 computed for time t=70.866764
# 2019-04-09 23:25:22,617 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:25:33,935 INFO CLAW: Solution 1 computed for time t=70.866529
# Time step 360 of 1800 - bed_max_delta 0.0004919507928104264
# 2019-04-09 23:25:34,374 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:25:46,264 INFO CLAW: Solution 1 computed for time t=70.866309
# 2019-04-09 23:25:46,702 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:25:57,417 INFO CLAW: Solution 1 computed for time t=70.866103
# 2019-04-09 23:25:57,797 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:26:08,757 INFO CLAW: Solution 1 computed for time t=70.865933
# 2019-04-09 23:26:09,123 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:26:20,262 INFO CLAW: Solution 1 computed for time t=70.865785
# 2019-04-09 23:26:20,588 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:26:31,790 INFO CLAW: Solution 1 computed for time t=70.865729
# 2019-04-09 23:26:32,126 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:26:43,200 INFO CLAW: Solution 1 computed for time t=70.865465
# 2019-04-09 23:26:43,592 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:26:54,832 INFO CLAW: Solution 1 computed for time t=70.865044
# 2019-04-09 23:26:55,447 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:27:06,550 INFO CLAW: Solution 1 computed for time t=70.864335
# 2019-04-09 23:27:06,877 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:27:18,137 INFO CLAW: Solution 1 computed for time t=70.863988
# 2019-04-09 23:27:18,830 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:27:30,957 INFO CLAW: Solution 1 computed for time t=70.863513
# 2019-04-09 23:27:31,486 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:27:43,729 INFO CLAW: Solution 1 computed for time t=70.863490
# 2019-04-09 23:27:44,241 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:27:55,935 INFO CLAW: Solution 1 computed for time t=70.863057
# 2019-04-09 23:27:56,347 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:28:07,125 INFO CLAW: Solution 1 computed for time t=70.862807
# 2019-04-09 23:28:07,530 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:28:19,670 INFO CLAW: Solution 1 computed for time t=70.862582
# 2019-04-09 23:28:20,316 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:28:36,405 INFO CLAW: Solution 1 computed for time t=70.861904
# 2019-04-09 23:28:37,145 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:28:51,115 INFO CLAW: Solution 1 computed for time t=70.861397
# 2019-04-09 23:28:51,830 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:29:06,190 INFO CLAW: Solution 1 computed for time t=70.860863
# 2019-04-09 23:29:07,565 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:29:20,075 INFO CLAW: Solution 1 computed for time t=70.860239
# 2019-04-09 23:29:20,596 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:29:33,323 INFO CLAW: Solution 1 computed for time t=70.859372
# 2019-04-09 23:29:33,944 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:29:45,158 INFO CLAW: Solution 1 computed for time t=70.858345
# 2019-04-09 23:29:45,670 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:29:57,694 INFO CLAW: Solution 1 computed for time t=70.857438
# 2019-04-09 23:29:58,230 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:30:14,191 INFO CLAW: Solution 1 computed for time t=70.856774
# 2019-04-09 23:30:14,826 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:30:27,328 INFO CLAW: Solution 1 computed for time t=70.856191
# 2019-04-09 23:30:27,875 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:30:40,971 INFO CLAW: Solution 1 computed for time t=70.855798
# 2019-04-09 23:30:41,474 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:30:56,714 INFO CLAW: Solution 1 computed for time t=70.855497
# 2019-04-09 23:30:57,237 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:31:08,478 INFO CLAW: Solution 1 computed for time t=70.855171
# 2019-04-09 23:31:08,996 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:31:20,374 INFO CLAW: Solution 1 computed for time t=70.854807
# 2019-04-09 23:31:20,881 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:31:31,850 INFO CLAW: Solution 1 computed for time t=70.854237
# 2019-04-09 23:31:32,415 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:31:44,781 INFO CLAW: Solution 1 computed for time t=70.853625
# 2019-04-09 23:31:45,277 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:31:56,251 INFO CLAW: Solution 1 computed for time t=70.852925
# 2019-04-09 23:31:56,755 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:32:07,670 INFO CLAW: Solution 1 computed for time t=70.852317
# 2019-04-09 23:32:08,151 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:32:19,609 INFO CLAW: Solution 1 computed for time t=70.851825
# 2019-04-09 23:32:19,953 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:32:30,813 INFO CLAW: Solution 1 computed for time t=70.851629
# 2019-04-09 23:32:31,382 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:32:42,451 INFO CLAW: Solution 1 computed for time t=70.851076
# 2019-04-09 23:32:42,904 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:32:54,261 INFO CLAW: Solution 1 computed for time t=70.850816
# 2019-04-09 23:32:54,676 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:33:05,566 INFO CLAW: Solution 1 computed for time t=70.850622
# 2019-04-09 23:33:06,134 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:33:17,130 INFO CLAW: Solution 1 computed for time t=70.850147
# 2019-04-09 23:33:17,553 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:33:28,871 INFO CLAW: Solution 1 computed for time t=70.849774
# 2019-04-09 23:33:29,332 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:33:40,410 INFO CLAW: Solution 1 computed for time t=70.849283
# 2019-04-09 23:33:40,852 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:33:51,716 INFO CLAW: Solution 1 computed for time t=70.848743
# Time step 480 of 1800 - bed_max_delta 0.0005371509375101044
# 2019-04-09 23:33:52,193 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:34:03,784 INFO CLAW: Solution 1 computed for time t=70.848201
# 2019-04-09 23:34:04,237 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:34:14,962 INFO CLAW: Solution 1 computed for time t=70.847711
# 2019-04-09 23:34:15,452 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:34:26,482 INFO CLAW: Solution 1 computed for time t=70.847296
# 2019-04-09 23:34:26,794 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:34:38,435 INFO CLAW: Solution 1 computed for time t=70.847077
# 2019-04-09 23:34:38,994 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:34:50,089 INFO CLAW: Solution 1 computed for time t=70.846590
# 2019-04-09 23:34:50,533 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:35:01,785 INFO CLAW: Solution 1 computed for time t=70.846254
# 2019-04-09 23:35:02,148 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:35:12,916 INFO CLAW: Solution 1 computed for time t=70.845989
# 2019-04-09 23:35:13,308 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:35:24,331 INFO CLAW: Solution 1 computed for time t=70.845670
# 2019-04-09 23:35:24,657 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:35:35,996 INFO CLAW: Solution 1 computed for time t=70.845467
# 2019-04-09 23:35:36,557 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:35:47,704 INFO CLAW: Solution 1 computed for time t=70.844990
# 2019-04-09 23:35:48,017 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:35:59,599 INFO CLAW: Solution 1 computed for time t=70.844753
# 2019-04-09 23:36:00,124 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:36:11,866 INFO CLAW: Solution 1 computed for time t=70.844243
# 2019-04-09 23:36:12,143 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:36:22,566 INFO CLAW: Solution 1 computed for time t=70.844059
# 2019-04-09 23:36:23,049 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:36:34,377 INFO CLAW: Solution 1 computed for time t=70.843561
# 2019-04-09 23:36:34,742 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:36:46,930 INFO CLAW: Solution 1 computed for time t=70.843257
# 2019-04-09 23:36:47,362 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:36:58,451 INFO CLAW: Solution 1 computed for time t=70.842921
# 2019-04-09 23:36:58,871 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:37:09,114 INFO CLAW: Solution 1 computed for time t=70.842627
# 2019-04-09 23:37:09,509 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:37:20,477 INFO CLAW: Solution 1 computed for time t=70.842323
# 2019-04-09 23:37:20,904 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:37:32,025 INFO CLAW: Solution 1 computed for time t=70.842000
# 2019-04-09 23:37:32,314 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:37:44,257 INFO CLAW: Solution 1 computed for time t=70.841800
# 2019-04-09 23:37:44,798 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:37:55,791 INFO CLAW: Solution 1 computed for time t=70.841331
# 2019-04-09 23:37:56,230 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:38:07,018 INFO CLAW: Solution 1 computed for time t=70.840960
# 2019-04-09 23:38:07,344 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:38:19,255 INFO CLAW: Solution 1 computed for time t=70.840742
# 2019-04-09 23:38:19,682 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:38:31,448 INFO CLAW: Solution 1 computed for time t=70.840367
# 2019-04-09 23:38:31,975 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:38:43,363 INFO CLAW: Solution 1 computed for time t=70.839829
# 2019-04-09 23:38:43,719 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:39:00,981 INFO CLAW: Solution 1 computed for time t=70.839612
# 2019-04-09 23:39:01,451 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:39:15,974 INFO CLAW: Solution 1 computed for time t=70.839092
# 2019-04-09 23:39:16,401 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:39:31,777 INFO CLAW: Solution 1 computed for time t=70.838884
# 2019-04-09 23:39:32,954 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:39:45,127 INFO CLAW: Solution 1 computed for time t=70.838369
# 2019-04-09 23:39:45,464 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:39:57,436 INFO CLAW: Solution 1 computed for time t=70.838198
# 2019-04-09 23:39:57,890 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:40:09,463 INFO CLAW: Solution 1 computed for time t=70.837703
# 2019-04-09 23:40:09,767 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:40:19,870 INFO CLAW: Solution 1 computed for time t=70.837548
# 2019-04-09 23:40:20,316 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:40:33,079 INFO CLAW: Solution 1 computed for time t=70.837093
# 2019-04-09 23:40:33,430 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:40:45,078 INFO CLAW: Solution 1 computed for time t=70.836949
# 2019-04-09 23:40:45,980 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:40:59,491 INFO CLAW: Solution 1 computed for time t=70.836490
# 2019-04-09 23:40:59,856 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:41:13,827 INFO CLAW: Solution 1 computed for time t=70.836329
# 2019-04-09 23:41:14,711 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:41:28,275 INFO CLAW: Solution 1 computed for time t=70.835834
# 2019-04-09 23:41:28,730 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:41:40,975 INFO CLAW: Solution 1 computed for time t=70.835605
# 2019-04-09 23:41:41,584 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:41:53,788 INFO CLAW: Solution 1 computed for time t=70.835272
# 2019-04-09 23:41:54,326 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:42:09,650 INFO CLAW: Solution 1 computed for time t=70.834802
# Time step 600 of 1800 - bed_max_delta 0.00043072931104463225
# 2019-04-09 23:42:10,069 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:42:20,957 INFO CLAW: Solution 1 computed for time t=70.834450
# 2019-04-09 23:42:21,435 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:42:32,315 INFO CLAW: Solution 1 computed for time t=70.834075
# 2019-04-09 23:42:32,727 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:42:45,326 INFO CLAW: Solution 1 computed for time t=70.833707
# 2019-04-09 23:42:45,812 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:42:58,548 INFO CLAW: Solution 1 computed for time t=70.833296
# 2019-04-09 23:42:59,092 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:43:11,970 INFO CLAW: Solution 1 computed for time t=70.832880
# 2019-04-09 23:43:12,403 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:43:25,274 INFO CLAW: Solution 1 computed for time t=70.832583
# 2019-04-09 23:43:25,891 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:43:37,415 INFO CLAW: Solution 1 computed for time t=70.832009
# 2019-04-09 23:43:37,859 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:43:51,738 INFO CLAW: Solution 1 computed for time t=70.831594
# 2019-04-09 23:43:52,160 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:44:03,041 INFO CLAW: Solution 1 computed for time t=70.831182
# 2019-04-09 23:44:03,388 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:44:14,565 INFO CLAW: Solution 1 computed for time t=70.830919
# 2019-04-09 23:44:15,083 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:44:26,490 INFO CLAW: Solution 1 computed for time t=70.830395
# 2019-04-09 23:44:26,893 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:44:38,223 INFO CLAW: Solution 1 computed for time t=70.830053
# 2019-04-09 23:44:38,573 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:44:49,820 INFO CLAW: Solution 1 computed for time t=70.829833
# 2019-04-09 23:44:50,538 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:45:03,431 INFO CLAW: Solution 1 computed for time t=70.829325
# 2019-04-09 23:45:03,908 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:45:15,687 INFO CLAW: Solution 1 computed for time t=70.829109
# 2019-04-09 23:45:16,168 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:45:33,519 INFO CLAW: Solution 1 computed for time t=70.828619
# 2019-04-09 23:45:33,961 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:45:45,740 INFO CLAW: Solution 1 computed for time t=70.828461
# 2019-04-09 23:45:46,158 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:46:03,418 INFO CLAW: Solution 1 computed for time t=70.828125
# 2019-04-09 23:46:03,818 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:46:14,808 INFO CLAW: Solution 1 computed for time t=70.827793
# 2019-04-09 23:46:15,187 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:46:26,560 INFO CLAW: Solution 1 computed for time t=70.827486
# 2019-04-09 23:46:27,082 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:46:38,744 INFO CLAW: Solution 1 computed for time t=70.827054
# 2019-04-09 23:46:39,120 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:46:50,513 INFO CLAW: Solution 1 computed for time t=70.826776
# 2019-04-09 23:46:50,935 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:47:01,748 INFO CLAW: Solution 1 computed for time t=70.826447
# 2019-04-09 23:47:02,227 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:47:14,015 INFO CLAW: Solution 1 computed for time t=70.826092
# 2019-04-09 23:47:14,420 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:47:25,476 INFO CLAW: Solution 1 computed for time t=70.825771
# 2019-04-09 23:47:25,899 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:47:37,000 INFO CLAW: Solution 1 computed for time t=70.825396
# 2019-04-09 23:47:37,606 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:47:48,809 INFO CLAW: Solution 1 computed for time t=70.825034
# 2019-04-09 23:47:49,257 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:48:00,358 INFO CLAW: Solution 1 computed for time t=70.824663
# 2019-04-09 23:48:00,798 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:48:12,210 INFO CLAW: Solution 1 computed for time t=70.824286
# 2019-04-09 23:48:12,645 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:48:23,844 INFO CLAW: Solution 1 computed for time t=70.823890
# 2019-04-09 23:48:24,232 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:48:35,451 INFO CLAW: Solution 1 computed for time t=70.823633
# 2019-04-09 23:48:35,937 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:48:47,779 INFO CLAW: Solution 1 computed for time t=70.823120
# 2019-04-09 23:48:48,095 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:48:59,281 INFO CLAW: Solution 1 computed for time t=70.822899
# 2019-04-09 23:48:59,782 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:49:10,779 INFO CLAW: Solution 1 computed for time t=70.822403
# 2019-04-09 23:49:11,088 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:49:22,812 INFO CLAW: Solution 1 computed for time t=70.822209
# 2019-04-09 23:49:23,310 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:49:34,530 INFO CLAW: Solution 1 computed for time t=70.821709
# 2019-04-09 23:49:34,823 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:49:45,766 INFO CLAW: Solution 1 computed for time t=70.821554
# 2019-04-09 23:49:46,271 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:49:58,474 INFO CLAW: Solution 1 computed for time t=70.821070
# 2019-04-09 23:49:58,730 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:50:09,694 INFO CLAW: Solution 1 computed for time t=70.820964
# 2019-04-09 23:50:10,087 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:50:22,479 INFO CLAW: Solution 1 computed for time t=70.820658
# Time step 720 of 1800 - bed_max_delta 0.0003954253129203125
# 2019-04-09 23:50:23,009 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:50:35,406 INFO CLAW: Solution 1 computed for time t=70.820269
# 2019-04-09 23:50:36,068 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:50:47,436 INFO CLAW: Solution 1 computed for time t=70.820027
# 2019-04-09 23:50:47,822 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:50:59,105 INFO CLAW: Solution 1 computed for time t=70.819750
# 2019-04-09 23:50:59,521 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:51:14,736 INFO CLAW: Solution 1 computed for time t=70.819461
# 2019-04-09 23:51:15,178 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:51:31,139 INFO CLAW: Solution 1 computed for time t=70.819122
# 2019-04-09 23:51:31,572 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:51:51,262 INFO CLAW: Solution 1 computed for time t=70.818777
# 2019-04-09 23:51:51,726 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:52:07,019 INFO CLAW: Solution 1 computed for time t=70.818390
# 2019-04-09 23:52:07,406 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:52:22,051 INFO CLAW: Solution 1 computed for time t=70.817997
# 2019-04-09 23:52:22,463 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:52:33,904 INFO CLAW: Solution 1 computed for time t=70.817590
# 2019-04-09 23:52:34,384 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:52:45,876 INFO CLAW: Solution 1 computed for time t=70.817193
# 2019-04-09 23:52:46,156 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:52:57,297 INFO CLAW: Solution 1 computed for time t=70.816974
# 2019-04-09 23:52:57,780 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:53:10,843 INFO CLAW: Solution 1 computed for time t=70.816488
# 2019-04-09 23:53:11,147 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:53:23,962 INFO CLAW: Solution 1 computed for time t=70.816276
# 2019-04-09 23:53:24,478 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:53:36,285 INFO CLAW: Solution 1 computed for time t=70.815807
# 2019-04-09 23:53:36,616 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:53:51,795 INFO CLAW: Solution 1 computed for time t=70.815674
# 2019-04-09 23:53:52,434 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:54:05,095 INFO CLAW: Solution 1 computed for time t=70.815200
# 2019-04-09 23:54:05,360 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:54:16,446 INFO CLAW: Solution 1 computed for time t=70.815088
# 2019-04-09 23:54:16,915 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:54:28,552 INFO CLAW: Solution 1 computed for time t=70.814640
# 2019-04-09 23:54:28,853 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:54:39,542 INFO CLAW: Solution 1 computed for time t=70.814546
# 2019-04-09 23:54:39,964 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:54:51,386 INFO CLAW: Solution 1 computed for time t=70.814197
# 2019-04-09 23:54:51,651 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:55:03,204 INFO CLAW: Solution 1 computed for time t=70.814080
# 2019-04-09 23:55:03,821 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:55:15,454 INFO CLAW: Solution 1 computed for time t=70.813687
# 2019-04-09 23:55:15,840 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:55:30,133 INFO CLAW: Solution 1 computed for time t=70.813407
# 2019-04-09 23:55:30,685 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:55:44,037 INFO CLAW: Solution 1 computed for time t=70.813154
# 2019-04-09 23:55:44,544 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:55:56,062 INFO CLAW: Solution 1 computed for time t=70.812851
# 2019-04-09 23:55:56,461 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:56:06,731 INFO CLAW: Solution 1 computed for time t=70.812546
# 2019-04-09 23:56:07,128 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:56:18,250 INFO CLAW: Solution 1 computed for time t=70.812218
# 2019-04-09 23:56:18,601 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:56:29,734 INFO CLAW: Solution 1 computed for time t=70.811883
# 2019-04-09 23:56:30,092 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:56:40,448 INFO CLAW: Solution 1 computed for time t=70.811534
# 2019-04-09 23:56:40,793 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:56:51,193 INFO CLAW: Solution 1 computed for time t=70.811219
# 2019-04-09 23:56:51,609 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:57:02,277 INFO CLAW: Solution 1 computed for time t=70.810825
# 2019-04-09 23:57:02,647 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:57:12,936 INFO CLAW: Solution 1 computed for time t=70.810472
# 2019-04-09 23:57:13,291 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:57:23,637 INFO CLAW: Solution 1 computed for time t=70.810120
# 2019-04-09 23:57:23,930 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:57:34,194 INFO CLAW: Solution 1 computed for time t=70.809894
# 2019-04-09 23:57:34,614 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:57:45,599 INFO CLAW: Solution 1 computed for time t=70.809463
# 2019-04-09 23:57:45,970 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:57:57,190 INFO CLAW: Solution 1 computed for time t=70.809284
# 2019-04-09 23:57:57,657 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:58:08,339 INFO CLAW: Solution 1 computed for time t=70.808839
# 2019-04-09 23:58:08,612 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:58:18,969 INFO CLAW: Solution 1 computed for time t=70.808674
# 2019-04-09 23:58:19,405 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:58:29,313 INFO CLAW: Solution 1 computed for time t=70.808237
# 2019-04-09 23:58:29,594 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:58:40,612 INFO CLAW: Solution 1 computed for time t=70.808052
# Time step 840 of 1800 - bed_max_delta 0.00035902029930036036
# 2019-04-09 23:58:41,021 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:58:51,292 INFO CLAW: Solution 1 computed for time t=70.807621
# 2019-04-09 23:58:51,556 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:59:02,566 INFO CLAW: Solution 1 computed for time t=70.807477
# 2019-04-09 23:59:02,975 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:59:13,020 INFO CLAW: Solution 1 computed for time t=70.807025
# 2019-04-09 23:59:13,365 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:59:22,913 INFO CLAW: Solution 1 computed for time t=70.806731
# 2019-04-09 23:59:23,264 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:59:32,845 INFO CLAW: Solution 1 computed for time t=70.806450
# 2019-04-09 23:59:33,194 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:59:43,392 INFO CLAW: Solution 1 computed for time t=70.806194
# 2019-04-09 23:59:43,803 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-09 23:59:54,891 INFO CLAW: Solution 1 computed for time t=70.805923
# 2019-04-09 23:59:55,229 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:00:07,306 INFO CLAW: Solution 1 computed for time t=70.805650
# 2019-04-10 00:00:07,654 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:00:17,960 INFO CLAW: Solution 1 computed for time t=70.805349
# 2019-04-10 00:00:18,331 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:00:28,247 INFO CLAW: Solution 1 computed for time t=70.805025
# 2019-04-10 00:00:28,620 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:00:38,263 INFO CLAW: Solution 1 computed for time t=70.804720
# 2019-04-10 00:00:38,641 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:00:49,243 INFO CLAW: Solution 1 computed for time t=70.804363
# 2019-04-10 00:00:49,597 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:00:59,254 INFO CLAW: Solution 1 computed for time t=70.804027
# 2019-04-10 00:00:59,621 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:01:09,452 INFO CLAW: Solution 1 computed for time t=70.803652
# 2019-04-10 00:01:09,850 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:01:20,045 INFO CLAW: Solution 1 computed for time t=70.803252
# 2019-04-10 00:01:20,429 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:01:30,511 INFO CLAW: Solution 1 computed for time t=70.802841
# 2019-04-10 00:01:30,853 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:01:40,846 INFO CLAW: Solution 1 computed for time t=70.802443
# 2019-04-10 00:01:41,110 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:01:51,328 INFO CLAW: Solution 1 computed for time t=70.802184
# 2019-04-10 00:01:51,746 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:02:01,389 INFO CLAW: Solution 1 computed for time t=70.801671
# 2019-04-10 00:02:01,651 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:02:11,348 INFO CLAW: Solution 1 computed for time t=70.801458
# 2019-04-10 00:02:11,744 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:02:21,783 INFO CLAW: Solution 1 computed for time t=70.801014
# 2019-04-10 00:02:22,119 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:02:31,731 INFO CLAW: Solution 1 computed for time t=70.800875
# 2019-04-10 00:02:32,101 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:02:41,733 INFO CLAW: Solution 1 computed for time t=70.800524
# 2019-04-10 00:02:42,016 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:02:51,783 INFO CLAW: Solution 1 computed for time t=70.800369
# 2019-04-10 00:02:52,150 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:03:03,104 INFO CLAW: Solution 1 computed for time t=70.800079
# 2019-04-10 00:03:03,441 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:03:13,033 INFO CLAW: Solution 1 computed for time t=70.799873
# 2019-04-10 00:03:13,369 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:03:23,010 INFO CLAW: Solution 1 computed for time t=70.799630
# 2019-04-10 00:03:23,343 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:03:33,683 INFO CLAW: Solution 1 computed for time t=70.799394
# 2019-04-10 00:03:34,046 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:03:43,822 INFO CLAW: Solution 1 computed for time t=70.799058
# 2019-04-10 00:03:44,133 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:03:53,810 INFO CLAW: Solution 1 computed for time t=70.798751
# 2019-04-10 00:03:54,134 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:04:04,210 INFO CLAW: Solution 1 computed for time t=70.798408
# 2019-04-10 00:04:04,550 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:04:14,226 INFO CLAW: Solution 1 computed for time t=70.798048
# 2019-04-10 00:04:14,572 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:04:24,257 INFO CLAW: Solution 1 computed for time t=70.797699
# 2019-04-10 00:04:24,509 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:04:34,872 INFO CLAW: Solution 1 computed for time t=70.797471
# 2019-04-10 00:04:35,256 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:04:45,114 INFO CLAW: Solution 1 computed for time t=70.797030
# ...
# 2019-04-10 00:35:14,187 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:35:23,565 INFO CLAW: Solution 1 computed for time t=70.756431
# 2019-04-10 00:35:23,784 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:35:33,216 INFO CLAW: Solution 1 computed for time t=70.756302
# 2019-04-10 00:35:33,581 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:35:43,226 INFO CLAW: Solution 1 computed for time t=70.756007
# 2019-04-10 00:35:43,439 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:35:52,953 INFO CLAW: Solution 1 computed for time t=70.755915
# 2019-04-10 00:35:53,242 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:36:02,828 INFO CLAW: Solution 1 computed for time t=70.755652
# 2019-04-10 00:36:03,039 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:36:12,615 INFO CLAW: Solution 1 computed for time t=70.755543
# 2019-04-10 00:36:12,915 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:36:22,582 INFO CLAW: Solution 1 computed for time t=70.755274
# 2019-04-10 00:36:22,792 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:36:32,467 INFO CLAW: Solution 1 computed for time t=70.755191
# 2019-04-10 00:36:32,826 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:36:42,255 INFO CLAW: Solution 1 computed for time t=70.754957
# 2019-04-10 00:36:42,447 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:36:52,312 INFO CLAW: Solution 1 computed for time t=70.754866
# 2019-04-10 00:36:52,629 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:37:02,139 INFO CLAW: Solution 1 computed for time t=70.754629
# 2019-04-10 00:37:02,358 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:37:11,843 INFO CLAW: Solution 1 computed for time t=70.754531
# 2019-04-10 00:37:12,157 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:37:22,228 INFO CLAW: Solution 1 computed for time t=70.754271
# 2019-04-10 00:37:22,447 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:37:31,981 INFO CLAW: Solution 1 computed for time t=70.754174
# 2019-04-10 00:37:32,297 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:37:41,728 INFO CLAW: Solution 1 computed for time t=70.753885
# 2019-04-10 00:37:41,943 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:37:51,343 INFO CLAW: Solution 1 computed for time t=70.753772
# 2019-04-10 00:37:51,635 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:38:01,525 INFO CLAW: Solution 1 computed for time t=70.753533
# 2019-04-10 00:38:01,734 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:38:11,298 INFO CLAW: Solution 1 computed for time t=70.753422
# 2019-04-10 00:38:11,622 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:38:21,045 INFO CLAW: Solution 1 computed for time t=70.753156
# 2019-04-10 00:38:21,250 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:38:30,964 INFO CLAW: Solution 1 computed for time t=70.753045
# 2019-04-10 00:38:31,311 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:38:40,714 INFO CLAW: Solution 1 computed for time t=70.752768
# 2019-04-10 00:38:40,908 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:38:50,448 INFO CLAW: Solution 1 computed for time t=70.752662
# 2019-04-10 00:38:50,769 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:39:00,611 INFO CLAW: Solution 1 computed for time t=70.752377
# 2019-04-10 00:39:00,813 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:39:10,156 INFO CLAW: Solution 1 computed for time t=70.752254
# 2019-04-10 00:39:10,503 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:39:19,928 INFO CLAW: Solution 1 computed for time t=70.751991
# 2019-04-10 00:39:20,125 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:39:29,830 INFO CLAW: Solution 1 computed for time t=70.751902
# Time step 1560 of 1800 - bed_max_delta 0.0002920326779415061
# 2019-04-10 00:39:30,227 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:39:39,738 INFO CLAW: Solution 1 computed for time t=70.751649
# 2019-04-10 00:39:39,947 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:39:49,346 INFO CLAW: Solution 1 computed for time t=70.751569
# 2019-04-10 00:39:49,656 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:39:59,150 INFO CLAW: Solution 1 computed for time t=70.751366
# 2019-04-10 00:39:59,360 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:40:09,268 INFO CLAW: Solution 1 computed for time t=70.751296
# 2019-04-10 00:40:09,570 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:40:19,016 INFO CLAW: Solution 1 computed for time t=70.751093
# 2019-04-10 00:40:19,224 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:40:28,760 INFO CLAW: Solution 1 computed for time t=70.751037
# 2019-04-10 00:40:29,044 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:40:38,862 INFO CLAW: Solution 1 computed for time t=70.750834
# 2019-04-10 00:40:39,078 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:40:48,554 INFO CLAW: Solution 1 computed for time t=70.750734
# 2019-04-10 00:40:48,846 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:40:58,429 INFO CLAW: Solution 1 computed for time t=70.750521
# 2019-04-10 00:40:58,624 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:41:08,288 INFO CLAW: Solution 1 computed for time t=70.750424
# 2019-04-10 00:41:08,590 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:41:18,101 INFO CLAW: Solution 1 computed for time t=70.750167
# 2019-04-10 00:41:18,297 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:41:27,935 INFO CLAW: Solution 1 computed for time t=70.750040
# 2019-04-10 00:41:28,296 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:41:37,720 INFO CLAW: Solution 1 computed for time t=70.749741
# 2019-04-10 00:41:37,946 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:41:47,801 INFO CLAW: Solution 1 computed for time t=70.749635
# 2019-04-10 00:41:48,148 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:41:57,744 INFO CLAW: Solution 1 computed for time t=70.749341
# 2019-04-10 00:41:57,945 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:42:07,370 INFO CLAW: Solution 1 computed for time t=70.749234
# 2019-04-10 00:42:07,565 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:42:17,264 INFO CLAW: Solution 1 computed for time t=70.749133
# 2019-04-10 00:42:17,532 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:42:26,991 INFO CLAW: Solution 1 computed for time t=70.748938
# 2019-04-10 00:42:27,250 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:42:36,710 INFO CLAW: Solution 1 computed for time t=70.748761
# 2019-04-10 00:42:36,970 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:42:46,716 INFO CLAW: Solution 1 computed for time t=70.748587
# 2019-04-10 00:42:46,974 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:42:56,360 INFO CLAW: Solution 1 computed for time t=70.748414
# 2019-04-10 00:42:56,699 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:43:06,333 INFO CLAW: Solution 1 computed for time t=70.748101
# 2019-04-10 00:43:06,595 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:43:15,997 INFO CLAW: Solution 1 computed for time t=70.747967
# 2019-04-10 00:43:16,212 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:43:25,949 INFO CLAW: Solution 1 computed for time t=70.747893
# 2019-04-10 00:43:26,263 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:43:35,669 INFO CLAW: Solution 1 computed for time t=70.747661
# 2019-04-10 00:43:35,880 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:43:45,382 INFO CLAW: Solution 1 computed for time t=70.747574
# 2019-04-10 00:43:45,700 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:43:55,707 INFO CLAW: Solution 1 computed for time t=70.747345
# 2019-04-10 00:43:55,921 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:44:05,529 INFO CLAW: Solution 1 computed for time t=70.747230
# 2019-04-10 00:44:05,846 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:44:15,315 INFO CLAW: Solution 1 computed for time t=70.746967
# 2019-04-10 00:44:15,518 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:44:25,244 INFO CLAW: Solution 1 computed for time t=70.746861
# 2019-04-10 00:44:25,578 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:44:35,079 INFO CLAW: Solution 1 computed for time t=70.746592
# 2019-04-10 00:44:35,291 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:44:44,685 INFO CLAW: Solution 1 computed for time t=70.746471
# 2019-04-10 00:44:44,977 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:44:54,626 INFO CLAW: Solution 1 computed for time t=70.746222
# 2019-04-10 00:44:54,851 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:45:04,415 INFO CLAW: Solution 1 computed for time t=70.746067
# 2019-04-10 00:45:04,676 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:45:14,086 INFO CLAW: Solution 1 computed for time t=70.745836
# 2019-04-10 00:45:14,417 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:45:23,862 INFO CLAW: Solution 1 computed for time t=70.745512
# 2019-04-10 00:45:24,150 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:45:33,939 INFO CLAW: Solution 1 computed for time t=70.745272
# 2019-04-10 00:45:34,189 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:45:43,700 INFO CLAW: Solution 1 computed for time t=70.745055
# 2019-04-10 00:45:43,975 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:45:53,433 INFO CLAW: Solution 1 computed for time t=70.744833
# 2019-04-10 00:45:53,661 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:46:03,680 INFO CLAW: Solution 1 computed for time t=70.744693
# Time step 1680 of 1800 - bed_max_delta 0.0003944942866249343
# 2019-04-10 00:46:03,997 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:46:13,538 INFO CLAW: Solution 1 computed for time t=70.744408
# 2019-04-10 00:46:13,766 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:46:23,253 INFO CLAW: Solution 1 computed for time t=70.744304
# 2019-04-10 00:46:23,586 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:46:33,639 INFO CLAW: Solution 1 computed for time t=70.744036
# 2019-04-10 00:46:33,866 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:46:43,269 INFO CLAW: Solution 1 computed for time t=70.743976
# 2019-04-10 00:46:43,610 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:46:53,058 INFO CLAW: Solution 1 computed for time t=70.743715
# 2019-04-10 00:46:53,258 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:47:02,870 INFO CLAW: Solution 1 computed for time t=70.743637
# 2019-04-10 00:47:03,171 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:47:12,882 INFO CLAW: Solution 1 computed for time t=70.743393
# 2019-04-10 00:47:13,119 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:47:22,596 INFO CLAW: Solution 1 computed for time t=70.743333
# 2019-04-10 00:47:22,903 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:47:32,394 INFO CLAW: Solution 1 computed for time t=70.743089
# 2019-04-10 00:47:32,587 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:47:42,201 INFO CLAW: Solution 1 computed for time t=70.742976
# 2019-04-10 00:47:42,532 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:47:52,048 INFO CLAW: Solution 1 computed for time t=70.742712
# 2019-04-10 00:47:52,310 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:48:01,855 INFO CLAW: Solution 1 computed for time t=70.742506
# 2019-04-10 00:48:02,081 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:48:11,880 INFO CLAW: Solution 1 computed for time t=70.742337
# 2019-04-10 00:48:12,148 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:48:21,544 INFO CLAW: Solution 1 computed for time t=70.742060
# 2019-04-10 00:48:21,758 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:48:31,151 INFO CLAW: Solution 1 computed for time t=70.741914
# 2019-04-10 00:48:31,487 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:48:41,005 INFO CLAW: Solution 1 computed for time t=70.741623
# 2019-04-10 00:48:41,274 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:48:50,861 INFO CLAW: Solution 1 computed for time t=70.741513
# 2019-04-10 00:48:51,159 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:49:00,775 INFO CLAW: Solution 1 computed for time t=70.741260
# 2019-04-10 00:49:00,996 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:49:10,512 INFO CLAW: Solution 1 computed for time t=70.741189
# 2019-04-10 00:49:10,717 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:49:20,591 INFO CLAW: Solution 1 computed for time t=70.741116
# 2019-04-10 00:49:20,945 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:49:30,533 INFO CLAW: Solution 1 computed for time t=70.740788
# 2019-04-10 00:49:30,735 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:49:40,211 INFO CLAW: Solution 1 computed for time t=70.740743
# 2019-04-10 00:49:40,527 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:49:50,315 INFO CLAW: Solution 1 computed for time t=70.740523
# 2019-04-10 00:49:50,501 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:50:00,093 INFO CLAW: Solution 1 computed for time t=70.740460
# 2019-04-10 00:50:00,483 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:50:09,909 INFO CLAW: Solution 1 computed for time t=70.740215
# 2019-04-10 00:50:10,096 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:50:20,107 INFO CLAW: Solution 1 computed for time t=70.740132
# 2019-04-10 00:50:20,487 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:50:30,041 INFO CLAW: Solution 1 computed for time t=70.739896
# 2019-04-10 00:50:30,210 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:50:39,690 INFO CLAW: Solution 1 computed for time t=70.739821
# 2019-04-10 00:50:40,004 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:50:49,504 INFO CLAW: Solution 1 computed for time t=70.739582
# 2019-04-10 00:50:49,710 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:50:59,518 INFO CLAW: Solution 1 computed for time t=70.739458
# 2019-04-10 00:50:59,821 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:51:09,645 INFO CLAW: Solution 1 computed for time t=70.739193
# 2019-04-10 00:51:09,856 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:51:19,375 INFO CLAW: Solution 1 computed for time t=70.739102
# 2019-04-10 00:51:19,686 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:51:29,728 INFO CLAW: Solution 1 computed for time t=70.738862
# 2019-04-10 00:51:29,925 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:51:39,419 INFO CLAW: Solution 1 computed for time t=70.738770
# 2019-04-10 00:51:39,696 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:51:49,259 INFO CLAW: Solution 1 computed for time t=70.738554
# 2019-04-10 00:51:49,474 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:51:59,236 INFO CLAW: Solution 1 computed for time t=70.738466
# 2019-04-10 00:51:59,466 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:52:09,081 INFO CLAW: Solution 1 computed for time t=70.738320
# 2019-04-10 00:52:09,274 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:52:18,752 INFO CLAW: Solution 1 computed for time t=70.738235
# 2019-04-10 00:52:19,107 INFO CLAW: Solution 0 computed for time t=0.000000
# 2019-04-10 00:52:28,899 INFO CLAW: Solution 1 computed for time t=70.737910
# Done

# %%
fig = plt.figure(figsize=(14, 4))
plt.plot(xc,surf)
plt.plot(xc,profileDf[starting_profile],'g')
plt.plot(xc,zc,'r')
#plt.plot(xc,profileDf['04'],'c')
#plt.plot(xc,profileDf['05'],'c')
plt.plot(xc,profileDf['06'],'c')
# Out:
# FigureCanvasNbAgg()

# %%
u.mean()
# Out:
# 0.5047756045946366

# %%
xc[1] - xc[0]
# Out:
# 0.015
