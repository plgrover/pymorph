# %% [markdown]
# # September 4, 2014

# %% [markdown]
# A couple of thoughts. Giri compared two models: equilibrium with slope modifier and a non-equilibrium model. They found that the slope modifier (graviational model?) introduced a lag similar to the non-equilibrium model which resulted in the formation of dunes. Giri mentioned that the non-equilibrium model required a finer grid than the equilibrium model.

# %%
import os, sys
from IPython.display import Math
from IPython.display import Latex
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

import numpy as np


pylab.rcParams['figure.figsize'] = 24, 12

sys.path.append("/pymorph")


import math
from sediment_transport import *
from copy import copy, deepcopy

from morph_geom_lib import *
from morph_lib import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# First run the code without the slope modification term.

# %%
x,zb = single_hump( 20., 201 )
zb0 = copy.deepcopy(zb)

depth = 2.5
qf = 0.45
timesteps = 1000
dt = 0.01
x,zb,u,qbs = morphmodel_2ndO_upwind(x,zb,depth,qf,timesteps,dt,False)

fig = plt.figure(figsize=(16, 4))
ax1 = fig.add_subplot(111)
ax1.plot(x,zb, label='bed')
ax1.plot(x,zb0, label='initial bed')
plt.show()
# Out:
# here 2
# Number of timesteps: 1000

# %% [markdown]
# Now re-run using the slope modifier. Here we are using the slope modification from Equation 87 in Dey and Papanicolaou 2008..

# %% [markdown]
# $$ Slope Adjustment = cos(\theta)\left(1 - \frac{tan(\theta)}{tan(\phi)} \right) $$

# %%
x,zb = single_hump( 20., 201 )
zb0 = copy.deepcopy(zb)

depth = 2.5
qf = 0.45
timesteps = 1000
dt = 0.01
x,zb,u,qbs = morphmodel_2ndO_upwind(x,zb,depth,qf,timesteps,dt, True)

fig = plt.figure(figsize=(16, 4))
ax1 = fig.add_subplot(111)
ax1.plot(x,zb, label='bed')
ax1.plot(x,zb0, label='initial bed')
plt.show()
# Out:
# here 2
# Number of timesteps: 1000
